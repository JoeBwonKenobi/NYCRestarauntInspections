# %% [markdown]
# # **Brooklyn Pizza Yelp API**

# %% [markdown]
# ## **Imports**

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## **Calling API**

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Login Key
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %% [markdown]
# ## **Defining Search Parameters**

# %%
# set our API call parameters and filename before the first call
location = 'Brooklyn, NY 11211'
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'Brooklyn'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Brooklyn-Pizza.json already exists.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 5500

# %%
results['region']
# Out:
# {'center': {'longitude': -73.94966125488281, 'latitude': 40.71264321986641}}

# %%
results['businesses']
# Out:
# [{'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1178,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 701.8952662330755},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2-U43PXg_c4tTOmeMnfSzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5116,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 3955.7678469664183},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_9LUY86MTKnc2UXug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 459,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7168952, 'longitude': -73.95892996733771},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 913.1197256251238},
#  {'id': 'WE_dce2JKcv-VoFNaqiJ4w',
#   'alias': 'carmines-pizzeria-brooklyn',
#   'name': "Carmine's Pizzeria",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V6LFN2p5zVHu78FvXnVZ7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carmines-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 539,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.714987, 'longitude': -73.94414},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '358 Graham Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187829659',
#   'display_phone': '(718) 782-9659',
#   'distance': 530.7604975886186},
#  {'id': '2FgUndzCT_jJATbmrBDVBg',
#   'alias': 'paulie-gees-slice-shop-brooklyn',
#   'name': "Paulie Gee's Slice Shop",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x01yyTgGYaW9b_YODsZgCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 364,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '110 Franklin St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#   'phone': '+19293376384',
#   'display_phone': '(929) 337-6384',
#   'distance': 1859.2440542825516},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cx9X4Q4-Visr4pzqYuNoEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3322,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 1574.938853168854},
#  {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#   'alias': 'rome-to-brooklyn-pizza-brooklyn-2',
#   'name': 'Rome To Brooklyn Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JavGLx9XtaLrrNzj36Vjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-brooklyn-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 171,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.711886016839244, 'longitude': -73.9429006},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17182693239',
#   'display_phone': '(718) 269-3239',
#   'distance': 576.0092018985303},
#  {'id': 'RqRCx09k0PZ4sZJgOxbAIA',
#   'alias': 'dough-vale-new-york',
#   'name': 'Dough Vale',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IUKwDlCnFx1-brvwmOjn_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dough-vale-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 113,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70933, 'longitude': -73.95407},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '330 S 3rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['330 S 3rd St', 'New York, NY 11211']},
#   'phone': '+13478897400',
#   'display_phone': '(347) 889-7400',
#   'distance': 535.4265025680102},
#  {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#   'alias': 'vinnies-pizzeria-brooklyn',
#   'name': "Vinnie's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-6rgJe3eIc87ZpsiftFESg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 760,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7189, 'longitude': -73.956843},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '148 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187827078',
#   'display_phone': '(718) 782-7078',
#   'distance': 925.627059811272},
#  {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#   'alias': 'paulie-gees-brooklyn',
#   'name': "Paulie Gee's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RCrEpYm1HSV3McDJIwq5Uw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1362,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+13479873747',
#   'display_phone': '(347) 987-3747',
#   'distance': 2018.1837198784995},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IBr5ZEI3nJBCwHYxcg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 6626,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 3997.176243345861},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FluVgKezP5ifs7greHV8Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2087,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 5635.742404027695},
#  {'id': 'r1PWMTbFXBmEhi0scGPf3w',
#   'alias': 'aces-pizza-brooklyn',
#   'name': "Ace's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/id-UXjLag2J47O_JkICU6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aces-pizza-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 174,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71505, 'longitude': -73.958365},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13477254366',
#   'display_phone': '(347) 725-4366',
#   'distance': 782.179585946517},
#  {'id': 'EsHcyOLHaK76bQuU7bwiTw',
#   'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3',
#   'name': "Tony's Pizzeria & Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/viqI7JzZtEW4qFW_JmpF0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 368,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.699286, 'longitude': -73.918724},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '443 Knickerbocker Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17184559664',
#   'display_phone': '(718) 455-9664',
#   'distance': 3001.095678100864},
#  {'id': 'ozYKGhJoGkQbFGskBeONuw',
#   'alias': 'the-original-square-of-soho-brooklyn',
#   'name': 'The Original Square Of Soho',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SlMVxJ6UCNf6ahRJHDz_NQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-original-square-of-soho-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 18,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70740304957788,
#    'longitude': -73.93186589137349},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2 Knickerbocker Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1609.135716699237},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/od36nFW220aMFAnNP00ocw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2718,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 3850.308194886269},
#  {'id': 'aPn2_EtjfHduXEmEBNxuFA',
#   'alias': 'rosas-pizza-brooklyn',
#   'name': "Rosa's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TtcGEKqRXYjkxNalZYapTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosas-pizza-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 199,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7139499, 'longitude': -73.95563},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '374 Metropolitan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['374 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17189632378',
#   'display_phone': '(718) 963-2378',
#   'distance': 529.6300466056173},
#  {'id': 'CFR-HzVHKWRMpMAR3LAhzg',
#   'alias': 'montesacro-pinseria-brooklyn-brooklyn',
#   'name': 'Montesacro Pinseria Brooklyn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5xTDQsC37mQ55E08iVxBxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/montesacro-pinseria-brooklyn-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 268,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71338, 'longitude': -73.95136},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '432 Union Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13479161062',
#   'display_phone': '(347) 916-1062',
#   'distance': 149.08787907869174},
#  {'id': 'Ii_CFGFaTUpfGH1xOUZXVQ',
#   'alias': 'rosie-pizza-bar-new-york',
#   'name': 'Rosie Pizza Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3hDs9vQsgH55e03l0ZUXQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosie-pizza-bar-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 67,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6998, 'longitude': -73.92842},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '128 Central Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 Central Ave', 'New York, NY 11221']},
#   'phone': '+17184404369',
#   'display_phone': '(718) 440-4369',
#   'distance': 2290.315340052384},
#  {'id': 'xv1Tdb7FhGBbySNfIt9pGQ',
#   'alias': 'williamsburg-pizza-brooklyn-6',
#   'name': 'Williamsburg Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WsjRUp8lZ26o-vCXiUzFOg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/williamsburg-pizza-brooklyn-6?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 367,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.7078768, 'longitude': -73.9507711},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '265 Union Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['265 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17188558729',
#   'display_phone': '(718) 855-8729',
#   'distance': 517.8448028552828}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                     alias  \
# 0   v1DHGRNCH9247WLYoaoA9A             l-industrie-pizzeria-brooklyn
# 1   zj8Lq1T8KIC5zwFief15jg            prince-street-pizza-new-york-2
# 2   GRXvvB1OKMuW4XDWEaVAlg                     joes-pizza-brooklyn-8
# 3   WE_dce2JKcv-VoFNaqiJ4w                carmines-pizzeria-brooklyn
# 4   2FgUndzCT_jJATbmrBDVBg           paulie-gees-slice-shop-brooklyn
# 5   FhXjAc6nKLf414KxYujUHw                       robertas-brooklyn-2
# 6   ON7ihGoWgZaBFDaLCYpk2Q         rome-to-brooklyn-pizza-brooklyn-2
# 7   RqRCx09k0PZ4sZJgOxbAIA                       dough-vale-new-york
# 8   lxPVSGnZ7YTiO5OGrqBS8Q                 vinnies-pizzeria-brooklyn
# 9   pGr5QuQU7Ur5GHLvXbT8bw                      paulie-gees-brooklyn
# 10  WIhm0W9197f_rRtDziq5qQ                lombardis-pizza-new-york-4
# 11  KEEXuHCYhsQJ-zpJhu98bA                   joes-pizza-new-york-148
# 12  r1PWMTbFXBmEhi0scGPf3w                       aces-pizza-brooklyn
# 13  EsHcyOLHaK76bQuU7bwiTw  tonys-pizzeria-and-restaurant-brooklyn-3
# 14  ozYKGhJoGkQbFGskBeONuw      the-original-square-of-soho-brooklyn
# 15  ysqgdbSrezXgVwER2kQWKA                       julianas-brooklyn-3
# 16  aPn2_EtjfHduXEmEBNxuFA                      rosas-pizza-brooklyn
# 17  CFR-HzVHKWRMpMAR3LAhzg     montesacro-pinseria-brooklyn-brooklyn
# 18  Ii_CFGFaTUpfGH1xOUZXVQ                  rosie-pizza-bar-new-york
# 19  xv1Tdb7FhGBbySNfIt9pGQ             williamsburg-pizza-brooklyn-6
#
#                             name  \
# 0           L'industrie Pizzeria
# 1            Prince Street Pizza
# 2                    Joe's Pizza
# 3             Carmine's Pizzeria
# 4        Paulie Gee's Slice Shop
# 5                      Roberta's
# 6         Rome To Brooklyn Pizza
# 7                     Dough Vale
# 8              Vinnie's Pizzeria
# 9                   Paulie Gee's
# 10              Lombardi's Pizza
# 11                   Joe's Pizza
# 12                   Ace's Pizza
# 13  Tony's Pizzeria & Restaurant
# 14   The Original Square Of Soho
# 15                     Juliana's
# 16                  Rosa's Pizza
# 17  Montesacro Pinseria Brooklyn
# 18               Rosie Pizza Bar
# 19            Williamsburg Pizza
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/2-U43P...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/V6LFN2...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/x01yyT...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/Cx9X4Q...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/4JavGL...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/IUKwDl...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/-6rgJe...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/RCrEpY...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IB...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/FluVgK...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/id-UXj...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/viqI7J...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/SlMVxJ...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/TtcGEK...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/5xTDQs...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/3hDs9v...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/WsjRUp...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/l-industrie-pizzeria-...          1178
# 1   https://www.yelp.com/biz/prince-street-pizza-n...          5116
# 2   https://www.yelp.com/biz/joes-pizza-brooklyn-8...           459
# 3   https://www.yelp.com/biz/carmines-pizzeria-bro...           539
# 4   https://www.yelp.com/biz/paulie-gees-slice-sho...           364
# 5   https://www.yelp.com/biz/robertas-brooklyn-2?a...          3322
# 6   https://www.yelp.com/biz/rome-to-brooklyn-pizz...           171
# 7   https://www.yelp.com/biz/dough-vale-new-york?a...           113
# 8   https://www.yelp.com/biz/vinnies-pizzeria-broo...           760
# 9   https://www.yelp.com/biz/paulie-gees-brooklyn?...          1362
# 10  https://www.yelp.com/biz/lombardis-pizza-new-y...          6626
# 11  https://www.yelp.com/biz/joes-pizza-new-york-1...          2087
# 12  https://www.yelp.com/biz/aces-pizza-brooklyn?a...           174
# 13  https://www.yelp.com/biz/tonys-pizzeria-and-re...           368
# 14  https://www.yelp.com/biz/the-original-square-o...            18
# 15  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2718
# 16  https://www.yelp.com/biz/rosas-pizza-brooklyn?...           199
# 17  https://www.yelp.com/biz/montesacro-pinseria-b...           268
# 18  https://www.yelp.com/biz/rosie-pizza-bar-new-y...            67
# 19  https://www.yelp.com/biz/williamsburg-pizza-br...           367
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 4   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 6   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 10             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 17  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 18             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
#
#                                           coordinates        transactions  \
# 0      {'latitude': 40.71162, 'longitude': -73.95783}          [delivery]
# 1   {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
# 2   {'latitude': 40.7168952, 'longitude': -73.9589...  [delivery, pickup]
# 3     {'latitude': 40.714987, 'longitude': -73.94414}  [delivery, pickup]
# 4       {'latitude': 40.72836, 'longitude': -73.9572}          [delivery]
# 5      {'latitude': 40.70493, 'longitude': -73.93399}  [delivery, pickup]
# 6   {'latitude': 40.711886016839244, 'longitude': ...  [delivery, pickup]
# 7      {'latitude': 40.70933, 'longitude': -73.95407}  [delivery, pickup]
# 8      {'latitude': 40.7189, 'longitude': -73.956843}  [delivery, pickup]
# 9    {'latitude': 40.729546, 'longitude': -73.958568}          [delivery]
# 10  {'latitude': 40.7215934960083, 'longitude': -7...  [delivery, pickup]
# 11      {'latitude': 40.7547, 'longitude': -73.98696}  [delivery, pickup]
# 12    {'latitude': 40.71505, 'longitude': -73.958365}          [delivery]
# 13   {'latitude': 40.699286, 'longitude': -73.918724}  [delivery, pickup]
# 14  {'latitude': 40.70740304957788, 'longitude': -...  [delivery, pickup]
# 15  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 16   {'latitude': 40.7139499, 'longitude': -73.95563}  [delivery, pickup]
# 17     {'latitude': 40.71338, 'longitude': -73.95136}  [delivery, pickup]
# 18      {'latitude': 40.6998, 'longitude': -73.92842}  [delivery, pickup]
# 19  {'latitude': 40.7078768, 'longitude': -73.9507...  [delivery, pickup]
#
#    price                                           location         phone  \
# 0      $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 1      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 2      $  {'address1': '216 Bedford Ave', 'address2': ''...  +17183882216
# 3     $$  {'address1': '358 Graham Ave', 'address2': '',...  +17187829659
# 4      $  {'address1': '110 Franklin St', 'address2': ''...  +19293376384
# 5     $$  {'address1': '261 Moore St', 'address2': '', '...  +17184171118
# 6    NaN  {'address1': '755 Grand St', 'address2': None,...  +17182693239
# 7     $$  {'address1': '330 S 3rd St', 'address2': None,...  +13478897400
# 8      $  {'address1': '148 Bedford Ave', 'address2': ''...  +17187827078
# 9     $$  {'address1': '60 Greenpoint Ave', 'address2': ...  +13479873747
# 10    $$  {'address1': '32 Spring St', 'address2': '', '...  +12129417994
# 11     $  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 12    $$  {'address1': '637 Driggs Ave', 'address2': '',...  +13477254366
# 13     $  {'address1': '443 Knickerbocker Ave', 'address...  +17184559664
# 14   NaN  {'address1': '2 Knickerbocker Ave', 'address2'...
# 15    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 16     $  {'address1': '374 Metropolitan Ave', 'address2...  +17189632378
# 17    $$  {'address1': '432 Union Ave', 'address2': None...  +13479161062
# 18    $$  {'address1': '128 Central Ave', 'address2': ''...  +17184404369
# 19     $  {'address1': '265 Union Ave', 'address2': '', ...  +17188558729
#
#      display_phone     distance
# 0   (718) 599-0002   701.895266
# 1   (212) 966-4100  3955.767847
# 2   (718) 388-2216   913.119726
# 3   (718) 782-9659   530.760498
# 4   (929) 337-6384  1859.244054
# 5   (718) 417-1118  1574.938853
# 6   (718) 269-3239   576.009202
# 7   (347) 889-7400   535.426503
# 8   (718) 782-7078   925.627060
# 9   (347) 987-3747  2018.183720
# 10  (212) 941-7994  3997.176243
# 11  (646) 559-4878  5635.742404
# 12  (347) 725-4366   782.179586
# 13  (718) 455-9664  3001.095678
# 14                  1609.135717
# 15  (718) 596-6700  3850.308195
# 16  (718) 963-2378   529.630047
# 17  (347) 916-1062   149.087879
# 18  (718) 440-4369  2290.315340
# 19  (718) 855-8729   517.844803

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 275

# %%
# Converting the JSON file to a dataframe
df = pd.read_json(JSON_FILE)

# %% [markdown]
# ## **Data Cleaning**

# %%
# Looking at the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             980 non-null    object
#  1   alias          980 non-null    object
#  2   name           980 non-null    object
#  3   image_url      980 non-null    object
#  4   is_closed      980 non-null    bool
#  5   url            980 non-null    object
#  6   review_count   980 non-null    int64
#  7   categories     980 non-null    object
#  8   rating         980 non-null    float64
#  9   coordinates    980 non-null    object
#  10  transactions   980 non-null    object
#  11  price          724 non-null    object
#  12  location       980 non-null    object
#  13  phone          980 non-null    object
#  14  display_phone  980 non-null    object
#  15  distance       980 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 115.9+ KB

# %%
# Dropping irrelevant columns that do not affect predicting the coorelation or good inspection scores to good yelp ratings
df.drop(['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'], axis=1, inplace=True)

# %%
# Function to filter out restaurants with 20 or fewer reviews
def filter_restaurants(df):
    filtered_dataframe = df[df['review_count'] >= 20]
    return filtered_dataframe

# executing function to eliminate restaurants with less than 20 reviews
df = filter_restaurants(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 0 to 979
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alias         847 non-null    object
#  1   name          847 non-null    object
#  2   image_url     847 non-null    object
#  3   url           847 non-null    object
#  4   review_count  847 non-null    int64
#  5   categories    847 non-null    object
#  6   rating        847 non-null    float64
#  7   coordinates   847 non-null    object
#  8   transactions  847 non-null    object
#  9   location      847 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 72.8+ KB

# %%
# Saving dataset to upload into other notebooks
df.to_csv('ydf', index=False)
