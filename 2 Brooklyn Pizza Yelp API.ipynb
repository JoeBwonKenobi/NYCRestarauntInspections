# %% [markdown]
# # **Brooklyn Pizza Yelp API**

# %% [markdown]
# ## **Imports**

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## **Calling API**

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Login Key
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %% [markdown]
# ## **Defining Search Parameters**

# %%
# set our API call parameters and filename before the first call
location = 'Brooklyn, NY 11211'
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'Brooklyn'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Brooklyn-Pizza.json already exists.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 6200

# %%
results['region']
# Out:
# {'center': {'longitude': -73.94966125488281, 'latitude': 40.71264321986641}}

# %%
results['businesses']
# Out:
# [{'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1310,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 701.8952662330755},
#  {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#   'alias': 'rome-to-brooklyn-pizza-brooklyn-2',
#   'name': 'Rome To Brooklyn Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JavGLx9XtaLrrNzj36Vjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-brooklyn-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 183,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.8,
#   'coordinates': {'latitude': 40.711886016839244, 'longitude': -73.9429006},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17182693239',
#   'display_phone': '(718) 269-3239',
#   'distance': 576.0092018985303},
#  {'id': 'r1PWMTbFXBmEhi0scGPf3w',
#   'alias': 'aces-pizza-brooklyn',
#   'name': "Ace's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/id-UXjLag2J47O_JkICU6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aces-pizza-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 201,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.71505, 'longitude': -73.958365},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13477254366',
#   'display_phone': '(347) 725-4366',
#   'distance': 782.179585946517},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e8enpWJ_fWrFXMNxhACfQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3324,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 1574.938853168854},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP5y6G_bG_g3H31fiw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5258,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 3955.7678469664183},
#  {'id': 'CFR-HzVHKWRMpMAR3LAhzg',
#   'alias': 'montesacro-pinseria-brooklyn-brooklyn',
#   'name': 'Montesacro Pinseria Brooklyn',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/A9l8TN1c_w9KN-PFjlXtZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/montesacro-pinseria-brooklyn-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 287,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.71338, 'longitude': -73.95136},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '432 Union Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13479161062',
#   'display_phone': '(347) 916-1062',
#   'distance': 149.08787907869174},
#  {'id': 'tpcCX_SHaNXqAzXOzbluJQ',
#   'alias': 'fini-pizza-brooklyn',
#   'name': 'Fini Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/harcCpQXJDORLLW0BFQNfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fini-pizza-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 159,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.71348, 'longitude': -73.96182},
#   'transactions': [],
#   'location': {'address1': '305 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['305 Bedford Ave', 'Brooklyn, NY 11211']},
#   'phone': '+19299693073',
#   'display_phone': '(929) 969-3073',
#   'distance': 1022.7361253733266},
#  {'id': 'LO2kgBEQZJ-ceFbj6-UaEA',
#   'alias': 'mos-general-pizza-and-provisions-brooklyn',
#   'name': "Mo's General Pizza & Provisions",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cIYsGoJtwXp-uf5Kn_aG_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mos-general-pizza-and-provisions-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 48,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.71562045514015, 'longitude': -73.9494481},
#   'transactions': [],
#   'location': {'address1': '620 Lorimer St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['620 Lorimer St', 'Brooklyn, NY 11211']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 331.5401933984459},
#  {'id': 'WE_dce2JKcv-VoFNaqiJ4w',
#   'alias': 'carmines-pizzeria-brooklyn',
#   'name': "Carmine's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ifwMwKV2JhREjjUFRg3qUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carmines-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 553,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.714987, 'longitude': -73.94414},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '358 Graham Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187829659',
#   'display_phone': '(718) 782-9659',
#   'distance': 530.7604975886186},
#  {'id': '2FgUndzCT_jJATbmrBDVBg',
#   'alias': 'paulie-gees-slice-shop-brooklyn',
#   'name': "Paulie Gee's Slice Shop",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/x01yyTgGYaW9b_YODsZgCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 394,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '110 Franklin St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#   'phone': '+19293376384',
#   'display_phone': '(929) 337-6384',
#   'distance': 1859.2440542825516},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_9LUY86MTKnc2UXug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 477,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7168952, 'longitude': -73.95892996733771},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 913.1197256251238},
#  {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#   'alias': 'paulie-gees-brooklyn',
#   'name': "Paulie Gee's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BgnKLCGphnQw_8jrltMlHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1375,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+13479873747',
#   'display_phone': '(347) 987-3747',
#   'distance': 2018.1837198784995},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/od36nFW220aMFAnNP00ocw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2750,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 3850.308194886269},
#  {'id': 'Ovniqgc47wZIEj-0rrEf3w',
#   'alias': 'macoletta-new-york-2',
#   'name': 'Macoletta',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c3GlZpR4AKFGR9g0yB0EKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/macoletta-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 33,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.7210325, 'longitude': -73.9601995},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '58 N 9th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['58 N 9th St', 'New York, NY 11249']},
#   'phone': '+16075667105',
#   'display_phone': '(607) 566-7105',
#   'distance': 1288.7236498438538},
#  {'id': 'G4KNXsc7F49OzkW7I28JCg',
#   'alias': 'best-pizza-brooklyn',
#   'name': 'Best Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k5nsYZTodSmt9MRnHHRYEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/best-pizza-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 749,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.7156, 'longitude': -73.95352},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '33 Havemeyer St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['33 Havemeyer St', 'Brooklyn, NY 11211']},
#   'phone': '+17185992210',
#   'display_phone': '(718) 599-2210',
#   'distance': 461.6016180439625},
#  {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#   'alias': 'vinnies-pizzeria-brooklyn',
#   'name': "Vinnie's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-6rgJe3eIc87ZpsiftFESg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 767,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.7189039, 'longitude': -73.95687904815627},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '148 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187827078',
#   'display_phone': '(718) 782-7078',
#   'distance': 924.4919505409122},
#  {'id': '-0vID-pN57SqpaYlmNYzXg',
#   'alias': 'pecoraro-latteria-brooklyn',
#   'name': 'Pecoraro Latteria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mjqNA8hSstmsQ5ZUovAF4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pecoraro-latteria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 78,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'gourmet', 'title': 'Specialty Food'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.8,
#   'coordinates': {'latitude': 40.714055, 'longitude': -73.947825},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '636 Metropolitian Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['636 Metropolitian Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13476901200',
#   'display_phone': '(347) 690-1200',
#   'distance': 216.48907423322567},
#  {'id': 'fg9VsI2rxjAHcGrvk0DDsQ',
#   'alias': 'greenpoint-original-italian-pizza-brooklyn',
#   'name': 'Greenpoint Original Italian Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/REEkEGB7vnQja5pOtOSDsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/greenpoint-original-italian-pizza-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 37,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.7256746906384,
#    'longitude': -73.9513858978921},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '93 Norman Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['93 Norman Ave', 'Brooklyn, NY 11222']},
#   'phone': '+19179091819',
#   'display_phone': '(917) 909-1819',
#   'distance': 1456.303155395669},
#  {'id': 'G77Q6kU-7qRefColCRTS0w',
#   'alias': 'robertas-brooklyn-5',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/naIec6omkhoRe6JWRFm8JQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-5?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 121,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.71618788546057,
#    'longitude': -73.96651754323669},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '6 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6 Grand St', 'Brooklyn, NY 11249']},
#   'phone': '+17182782400',
#   'display_phone': '(718) 278-2400',
#   'distance': 1474.3494499312937},
#  {'id': '1yd-Hq0UFuKN4bY6X2hYVQ',
#   'alias': 'sals-pizzeria-brooklyn',
#   'name': "Sal's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qYQ796WTXf8_dyZTfvVMNw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sals-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 210,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.71322, 'longitude': -73.94911},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '544 Lorimer St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['544 Lorimer St', 'Brooklyn, NY 11211']},
#   'phone': '+17183886838',
#   'display_phone': '(718) 388-6838',
#   'distance': 79.07588560963505}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                       alias  \
# 0   v1DHGRNCH9247WLYoaoA9A               l-industrie-pizzeria-brooklyn
# 1   ON7ihGoWgZaBFDaLCYpk2Q           rome-to-brooklyn-pizza-brooklyn-2
# 2   r1PWMTbFXBmEhi0scGPf3w                         aces-pizza-brooklyn
# 3   FhXjAc6nKLf414KxYujUHw                         robertas-brooklyn-2
# 4   zj8Lq1T8KIC5zwFief15jg              prince-street-pizza-new-york-2
# 5   CFR-HzVHKWRMpMAR3LAhzg       montesacro-pinseria-brooklyn-brooklyn
# 6   tpcCX_SHaNXqAzXOzbluJQ                         fini-pizza-brooklyn
# 7   LO2kgBEQZJ-ceFbj6-UaEA   mos-general-pizza-and-provisions-brooklyn
# 8   WE_dce2JKcv-VoFNaqiJ4w                  carmines-pizzeria-brooklyn
# 9   2FgUndzCT_jJATbmrBDVBg             paulie-gees-slice-shop-brooklyn
# 10  GRXvvB1OKMuW4XDWEaVAlg                       joes-pizza-brooklyn-8
# 11  pGr5QuQU7Ur5GHLvXbT8bw                        paulie-gees-brooklyn
# 12  ysqgdbSrezXgVwER2kQWKA                         julianas-brooklyn-3
# 13  Ovniqgc47wZIEj-0rrEf3w                        macoletta-new-york-2
# 14  G4KNXsc7F49OzkW7I28JCg                         best-pizza-brooklyn
# 15  lxPVSGnZ7YTiO5OGrqBS8Q                   vinnies-pizzeria-brooklyn
# 16  -0vID-pN57SqpaYlmNYzXg                  pecoraro-latteria-brooklyn
# 17  fg9VsI2rxjAHcGrvk0DDsQ  greenpoint-original-italian-pizza-brooklyn
# 18  G77Q6kU-7qRefColCRTS0w                         robertas-brooklyn-5
# 19  1yd-Hq0UFuKN4bY6X2hYVQ                      sals-pizzeria-brooklyn
#
#                                  name  \
# 0                L'industrie Pizzeria
# 1              Rome To Brooklyn Pizza
# 2                         Ace's Pizza
# 3                           Roberta's
# 4                 Prince Street Pizza
# 5        Montesacro Pinseria Brooklyn
# 6                          Fini Pizza
# 7     Mo's General Pizza & Provisions
# 8                  Carmine's Pizzeria
# 9             Paulie Gee's Slice Shop
# 10                        Joe's Pizza
# 11                       Paulie Gee's
# 12                          Juliana's
# 13                          Macoletta
# 14                         Best Pizza
# 15                  Vinnie's Pizzeria
# 16                  Pecoraro Latteria
# 17  Greenpoint Original Italian Pizza
# 18                          Roberta's
# 19                     Sal's Pizzeria
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/4JavGL...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/id-UXj...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/e8enpW...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/A9l8TN...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/harcCp...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/cIYsGo...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/ifwMwK...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/x01yyT...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/BgnKLC...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/c3GlZp...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/k5nsYZ...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/-6rgJe...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/mjqNA8...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/REEkEG...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/naIec6...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/qYQ796...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/l-industrie-pizzeria-...          1310
# 1   https://www.yelp.com/biz/rome-to-brooklyn-pizz...           183
# 2   https://www.yelp.com/biz/aces-pizza-brooklyn?a...           201
# 3   https://www.yelp.com/biz/robertas-brooklyn-2?a...          3324
# 4   https://www.yelp.com/biz/prince-street-pizza-n...          5258
# 5   https://www.yelp.com/biz/montesacro-pinseria-b...           287
# 6   https://www.yelp.com/biz/fini-pizza-brooklyn?a...           159
# 7   https://www.yelp.com/biz/mos-general-pizza-and...            48
# 8   https://www.yelp.com/biz/carmines-pizzeria-bro...           553
# 9   https://www.yelp.com/biz/paulie-gees-slice-sho...           394
# 10  https://www.yelp.com/biz/joes-pizza-brooklyn-8...           477
# 11  https://www.yelp.com/biz/paulie-gees-brooklyn?...          1375
# 12  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2750
# 13  https://www.yelp.com/biz/macoletta-new-york-2?...            33
# 14  https://www.yelp.com/biz/best-pizza-brooklyn?a...           749
# 15  https://www.yelp.com/biz/vinnies-pizzeria-broo...           767
# 16  https://www.yelp.com/biz/pecoraro-latteria-bro...            78
# 17  https://www.yelp.com/biz/greenpoint-original-i...            37
# 18  https://www.yelp.com/biz/robertas-brooklyn-5?a...           121
# 19  https://www.yelp.com/biz/sals-pizzeria-brookly...           210
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.7
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.8
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.7
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 4   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 5   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.4
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 9   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 10             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 12             [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.7
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     3.8
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.1
# 16  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.8
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 18             [{'alias': 'pizza', 'title': 'Pizza'}]     3.9
# 19  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.8
#
#                                           coordinates        transactions  \
# 0      {'latitude': 40.71162, 'longitude': -73.95783}          [delivery]
# 1   {'latitude': 40.711886016839244, 'longitude': ...  [pickup, delivery]
# 2     {'latitude': 40.71505, 'longitude': -73.958365}  [pickup, delivery]
# 3      {'latitude': 40.70493, 'longitude': -73.93399}  [pickup, delivery]
# 4   {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 5      {'latitude': 40.71338, 'longitude': -73.95136}  [pickup, delivery]
# 6      {'latitude': 40.71348, 'longitude': -73.96182}                  []
# 7   {'latitude': 40.71562045514015, 'longitude': -...                  []
# 8     {'latitude': 40.714987, 'longitude': -73.94414}  [pickup, delivery]
# 9       {'latitude': 40.72836, 'longitude': -73.9572}          [delivery]
# 10  {'latitude': 40.7168952, 'longitude': -73.9589...  [pickup, delivery]
# 11   {'latitude': 40.729546, 'longitude': -73.958568}            [pickup]
# 12  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 13  {'latitude': 40.7210325, 'longitude': -73.9601...  [pickup, delivery]
# 14      {'latitude': 40.7156, 'longitude': -73.95352}  [pickup, delivery]
# 15  {'latitude': 40.7189039, 'longitude': -73.9568...  [pickup, delivery]
# 16   {'latitude': 40.714055, 'longitude': -73.947825}  [pickup, delivery]
# 17  {'latitude': 40.7256746906384, 'longitude': -7...  [pickup, delivery]
# 18  {'latitude': 40.71618788546057, 'longitude': -...  [pickup, delivery]
# 19     {'latitude': 40.71322, 'longitude': -73.94911}  [pickup, delivery]
#
#    price                                           location         phone  \
# 0      $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 1    NaN  {'address1': '755 Grand St', 'address2': None,...  +17182693239
# 2     $$  {'address1': '637 Driggs Ave', 'address2': '',...  +13477254366
# 3     $$  {'address1': '261 Moore St', 'address2': '', '...  +17184171118
# 4      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 5     $$  {'address1': '432 Union Ave', 'address2': None...  +13479161062
# 6    NaN  {'address1': '305 Bedford Ave', 'address2': ''...  +19299693073
# 7    NaN  {'address1': '620 Lorimer St', 'address2': '',...
# 8     $$  {'address1': '358 Graham Ave', 'address2': '',...  +17187829659
# 9      $  {'address1': '110 Franklin St', 'address2': ''...  +19293376384
# 10    $$  {'address1': '216 Bedford Ave', 'address2': ''...  +17183882216
# 11    $$  {'address1': '60 Greenpoint Ave', 'address2': ...  +13479873747
# 12    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 13   NaN  {'address1': '58 N 9th St', 'address2': None, ...  +16075667105
# 14     $  {'address1': '33 Havemeyer St', 'address2': ''...  +17185992210
# 15     $  {'address1': '148 Bedford Ave', 'address2': ''...  +17187827078
# 16   NaN  {'address1': '636 Metropolitian Ave', 'address...  +13476901200
# 17   NaN  {'address1': '93 Norman Ave', 'address2': '', ...  +19179091819
# 18   NaN  {'address1': '6 Grand St', 'address2': '', 'ad...  +17182782400
# 19     $  {'address1': '544 Lorimer St', 'address2': '',...  +17183886838
#
#      display_phone     distance
# 0   (718) 599-0002   701.895266
# 1   (718) 269-3239   576.009202
# 2   (347) 725-4366   782.179586
# 3   (718) 417-1118  1574.938853
# 4   (212) 966-4100  3955.767847
# 5   (347) 916-1062   149.087879
# 6   (929) 969-3073  1022.736125
# 7                    331.540193
# 8   (718) 782-9659   530.760498
# 9   (929) 337-6384  1859.244054
# 10  (718) 388-2216   913.119726
# 11  (347) 987-3747  2018.183720
# 12  (718) 596-6700  3850.308195
# 13  (607) 566-7105  1288.723650
# 14  (718) 599-2210   461.601618
# 15  (718) 782-7078   924.491951
# 16  (347) 690-1200   216.489074
# 17  (917) 909-1819  1456.303155
# 18  (718) 278-2400  1474.349450
# 19  (718) 388-6838    79.075886

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 310

# %%
# Converting the JSON file to a dataframe
df = pd.read_json(JSON_FILE)

# %% [markdown]
# ## **Data Cleaning**

# %%
# Looking at the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             980 non-null    object
#  1   alias          980 non-null    object
#  2   name           980 non-null    object
#  3   image_url      980 non-null    object
#  4   is_closed      980 non-null    bool
#  5   url            980 non-null    object
#  6   review_count   980 non-null    int64
#  7   categories     980 non-null    object
#  8   rating         980 non-null    float64
#  9   coordinates    980 non-null    object
#  10  transactions   980 non-null    object
#  11  price          724 non-null    object
#  12  location       980 non-null    object
#  13  phone          980 non-null    object
#  14  display_phone  980 non-null    object
#  15  distance       980 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 115.9+ KB

# %%
# Dropping irrelevant columns that do not affect predicting the coorelation or good inspection scores to good yelp ratings
df.drop(['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'], axis=1, inplace=True)

# %%
# Function to filter out restaurants with 20 or fewer reviews
def filter_restaurants(df):
    filtered_dataframe = df[df['review_count'] >= 20]
    return filtered_dataframe

# executing function to eliminate restaurants with less than 20 reviews
df = filter_restaurants(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 0 to 979
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alias         847 non-null    object
#  1   name          847 non-null    object
#  2   image_url     847 non-null    object
#  3   url           847 non-null    object
#  4   review_count  847 non-null    int64
#  5   categories    847 non-null    object
#  6   rating        847 non-null    float64
#  7   coordinates   847 non-null    object
#  8   transactions  847 non-null    object
#  9   location      847 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 72.8+ KB

# %%
# Saving dataset to upload into other notebooks
df.to_csv('ydf', index=False)
