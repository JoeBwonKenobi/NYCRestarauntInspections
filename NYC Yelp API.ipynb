# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Login Key
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'Manhattan'
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'Manhattan'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Manhattan-Pizza.json already exists.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 10000

# %%
results['region']
# Out:
# {'center': {'longitude': -73.96957397460938, 'latitude': 40.75917470627005}}

# %%
results['businesses']
# Out:
# [{'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#   'alias': 'my-pie-pizzeria-romana-new-york-2',
#   'name': 'My Pie Pizzeria Romana',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b3BIzM5lgmuF-W7owEx5xQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 927,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '690 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#   'phone': '+12123171850',
#   'display_phone': '(212) 317-1850',
#   'distance': 186.58214310058082},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FluVgKezP5ifs7greHV8Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2209,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 1552.86453787486},
#  {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#   'alias': 'ny-pizza-suprema-new-york',
#   'name': 'NY Pizza Suprema',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2600,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.7502059936523,
#    'longitude': -73.9953231811523},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'phone': '+12125948939',
#   'display_phone': '(212) 594-8939',
#   'distance': 2387.061954989499},
#  {'id': 'ypJRRRKZtaNad--1EbRBTg',
#   'alias': 'roma-pizza-and-restaurant-new-york',
#   'name': 'Roma Pizza & Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LA5DKU89rzsD41Hta-ECpg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roma-pizza-and-restaurant-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 23,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.751211, 'longitude': -73.986364},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '980 6th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['980 6th Ave', 'New York, NY 10018']},
#   'phone': '+12124578555',
#   'display_phone': '(212) 457-8555',
#   'distance': 1669.7516613878195},
#  {'id': 'YchMTqpM6xksrpqXR0YUrQ',
#   'alias': 'xeno-s-pizza-new-york',
#   'name': 'Xeno’s Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dVkXWNvDYPgZ7OesI246Kw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/xeno-s-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 36,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.75728, 'longitude': -73.97008},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '163 E 52nd St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['163 E 52nd St', 'New York, NY 10022']},
#   'phone': '+16469520030',
#   'display_phone': '(646) 952-0030',
#   'distance': 210.61563672529866},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP5y6G_bG_g3H31fiw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5236,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 4530.158358332591},
#  {'id': 'EXQ0x2W9RTydIlHAU9MU1A',
#   'alias': 'mimis-pizza-east-86th-new-york-2',
#   'name': "Mimi's Pizza - East 86th",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/btcWJW_uNq7JEwk2wFMtiQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mimis-pizza-east-86th-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 187,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.778638, 'longitude': -73.952895},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '217 E 86th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['217 E 86th St', 'New York, NY 10028']},
#   'phone': '+16468612518',
#   'display_phone': '(646) 861-2518',
#   'distance': 2577.9373154983723},
#  {'id': 'tRIHhPKryUZ56SfIz6mLiA',
#   'alias': 'angelos-coal-oven-pizzeria-new-york',
#   'name': "Angelo's Coal Oven Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_DsPiET9EnikFNy-AvoVxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/angelos-coal-oven-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1278,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76492, 'longitude': -73.97794},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '117 W 57th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['117 W 57th St', 'New York, NY 10019']},
#   'phone': '+12123334333',
#   'display_phone': '(212) 333-4333',
#   'distance': 949.9772407230507},
#  {'id': 'KEgdfVEVVgJFnGFiLNPDzQ',
#   'alias': 'sofia-pizza-shoppe-new-york',
#   'name': 'Sofia Pizza Shoppe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XTOP8koYT-ccWAPx2cUIKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sofia-pizza-shoppe-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 257,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.75674, 'longitude': -73.96431},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '989 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['989 1st Ave', 'New York, NY 10022']},
#   'phone': '+12128888816',
#   'display_phone': '(212) 888-8816',
#   'distance': 520.3312331060953},
#  {'id': 'G9hV4H2iGpWD8RoUpjtokg',
#   'alias': 'l-industrie-pizzeria-new-york',
#   'name': 'L’industrie Pizzeria',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hzdlv1PI6ZM60HzVwxUc8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 194,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 40.73323443774397, 'longitude': -74.0049081},
#   'transactions': [],
#   'location': {'address1': '104 Christopher St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['104 Christopher St', 'New York, NY 10014']},
#   'phone': '+12122560648',
#   'display_phone': '(212) 256-0648',
#   'distance': 4144.896541579684},
#  {'id': 'GgdR6L49eKH5drPaOYOOPQ',
#   'alias': 'pops-pizzas-new-york',
#   'name': "Pop's Pizzas",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K51H3tN_XFj8LCYv5raNWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pops-pizzas-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 213,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 40.767085, 'longitude': -73.983103},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '301 West 57th St',
#    'address2': 'Ground Fl',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['301 West 57th St', 'Ground Fl', 'New York, NY 10019']},
#   'phone': '+12127848863',
#   'display_phone': '(212) 784-8863',
#   'distance': 1440.0598002104812},
#  {'id': 'XujJhk-uQQezYgxyx-YN5Q',
#   'alias': 'parla-new-york',
#   'name': 'Parla',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-zBCqQN4Jqa8wuxKSU-Y_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/parla-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 66,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.779604142118245,
#    'longitude': -73.9775782278624},
#   'transactions': [],
#   'location': {'address1': '320 Columbus Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['320 Columbus Ave', 'New York, NY 10023']},
#   'phone': '+12127029006',
#   'display_phone': '(212) 702-9006',
#   'distance': 2369.5437016537244},
#  {'id': 'AOZlppihRNG8Y2N4Jid30A',
#   'alias': 'brooklyn-pizza-masters-new-york',
#   'name': 'Brooklyn Pizza Masters',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Dko2ofSegIWoF3n57Y5ISQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyn-pizza-masters-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 254,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.75869828079016,
#    'longitude': -73.962919097227},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1055 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1055 1st Ave', 'New York, NY 10022']},
#   'phone': '+16466697757',
#   'display_phone': '(646) 669-7757',
#   'distance': 563.0113927421821},
#  {'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1288,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 5382.969880738413},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IBr5ZEI3nJBCwHYxcg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 6623,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 4718.99145813924},
#  {'id': 'peV8B-MMMZb1mrC9r6rfAA',
#   'alias': 'lucia-of-soho-new-york',
#   'name': 'Lucia of Soho',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ciK5mi9B4YZLzMgbrb1eUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucia-of-soho-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 57,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.721416405112784, 'longitude': -74.0043748},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '375 Canal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['375 Canal St', 'New York, NY 10013']},
#   'phone': '+19179652900',
#   'display_phone': '(917) 965-2900',
#   'distance': 5120.936130362317},
#  {'id': 'vVVmHacu2YAxKfpIjhfd1g',
#   'alias': 'norma-new-york-5',
#   'name': 'Norma',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qJKt5l2xSBUKOFRA6UOqVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/norma-new-york-5?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 657,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.743553, 'longitude': -73.980026},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '438 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['438 3rd Ave', 'New York, NY 10016']},
#   'phone': '+12128890600',
#   'display_phone': '(212) 889-0600',
#   'distance': 1942.2913842319626},
#  {'id': 'xsQTIeq-WLkp4ParkTQpMQ',
#   'alias': 'pizzarte-new-york',
#   'name': 'PizzArte',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FD2amDUAhuqIyRcd_S7d-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzarte-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1326,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.7629335072372,
#    'longitude': -73.9776668697596},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '69 W 55th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 W 55th St', 'New York, NY 10019']},
#   'phone': '+12122473936',
#   'display_phone': '(212) 247-3936',
#   'distance': 799.5513204887},
#  {'id': '2-GsvFaQpVpbaIdwb9lSeQ',
#   'alias': 'andiamo-pizza-new-york-2',
#   'name': 'Andiamo Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0SPjEd6UA3mn5ZJqLMt7LA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/andiamo-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 164,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.746144, 'longitude': -73.990189},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '818 6th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['818 6th Ave', 'New York, NY 10001']},
#   'phone': '+12122542860',
#   'display_phone': '(212) 254-2860',
#   'distance': 2263.1122742182406},
#  {'id': 'fyC2cBsQ0FsMJmv0jSworg',
#   'alias': 'donna-margherita-new-york',
#   'name': 'Donna Margherita',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/39j5RwuLSW8nJoSpzEOtAA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/donna-margherita-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 200,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 40.76652, 'longitude': -73.9598},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1304 2nd Ave',
#    'address2': 'Ste A',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10065',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1304 2nd Ave', 'Ste A', 'New York, NY 10065']},
#   'phone': '+12127721169',
#   'display_phone': '(212) 772-1169',
#   'distance': 1158.3024402854205}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                alias  \
# 0   oRdM7n-AfBPBGAlH4Q0Sag    my-pie-pizzeria-romana-new-york-2
# 1   KEEXuHCYhsQJ-zpJhu98bA              joes-pizza-new-york-148
# 2   -9NO2IDCJMyNGZMAQ1-VQw            ny-pizza-suprema-new-york
# 3   ypJRRRKZtaNad--1EbRBTg   roma-pizza-and-restaurant-new-york
# 4   YchMTqpM6xksrpqXR0YUrQ                xeno-s-pizza-new-york
# 5   zj8Lq1T8KIC5zwFief15jg       prince-street-pizza-new-york-2
# 6   EXQ0x2W9RTydIlHAU9MU1A     mimis-pizza-east-86th-new-york-2
# 7   tRIHhPKryUZ56SfIz6mLiA  angelos-coal-oven-pizzeria-new-york
# 8   KEgdfVEVVgJFnGFiLNPDzQ          sofia-pizza-shoppe-new-york
# 9   G9hV4H2iGpWD8RoUpjtokg        l-industrie-pizzeria-new-york
# 10  GgdR6L49eKH5drPaOYOOPQ                 pops-pizzas-new-york
# 11  XujJhk-uQQezYgxyx-YN5Q                       parla-new-york
# 12  AOZlppihRNG8Y2N4Jid30A      brooklyn-pizza-masters-new-york
# 13  v1DHGRNCH9247WLYoaoA9A        l-industrie-pizzeria-brooklyn
# 14  WIhm0W9197f_rRtDziq5qQ           lombardis-pizza-new-york-4
# 15  peV8B-MMMZb1mrC9r6rfAA               lucia-of-soho-new-york
# 16  vVVmHacu2YAxKfpIjhfd1g                     norma-new-york-5
# 17  xsQTIeq-WLkp4ParkTQpMQ                    pizzarte-new-york
# 18  2-GsvFaQpVpbaIdwb9lSeQ             andiamo-pizza-new-york-2
# 19  fyC2cBsQ0FsMJmv0jSworg            donna-margherita-new-york
#
#                            name  \
# 0        My Pie Pizzeria Romana
# 1                   Joe's Pizza
# 2              NY Pizza Suprema
# 3       Roma Pizza & Restaurant
# 4                  Xeno’s Pizza
# 5           Prince Street Pizza
# 6      Mimi's Pizza - East 86th
# 7   Angelo's Coal Oven Pizzeria
# 8            Sofia Pizza Shoppe
# 9          L’industrie Pizzeria
# 10                 Pop's Pizzas
# 11                        Parla
# 12       Brooklyn Pizza Masters
# 13         L'industrie Pizzeria
# 14             Lombardi's Pizza
# 15                Lucia of Soho
# 16                        Norma
# 17                     PizzArte
# 18                Andiamo Pizza
# 19             Donna Margherita
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/b3BIzM...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/FluVgK...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXn...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/LA5DKU...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/dVkXWN...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/Jo9jBP...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/btcWJW...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/_DsPiE...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/XTOP8k...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/Hzdlv1...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/K51H3t...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/-zBCqQ...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/Dko2of...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IB...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/ciK5mi...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/qJKt5l...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/FD2amD...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/0SPjEd...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/39j5Rw...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/my-pie-pizzeria-roman...           927
# 1   https://www.yelp.com/biz/joes-pizza-new-york-1...          2209
# 2   https://www.yelp.com/biz/ny-pizza-suprema-new-...          2600
# 3   https://www.yelp.com/biz/roma-pizza-and-restau...            23
# 4   https://www.yelp.com/biz/xeno-s-pizza-new-york...            36
# 5   https://www.yelp.com/biz/prince-street-pizza-n...          5236
# 6   https://www.yelp.com/biz/mimis-pizza-east-86th...           187
# 7   https://www.yelp.com/biz/angelos-coal-oven-piz...          1278
# 8   https://www.yelp.com/biz/sofia-pizza-shoppe-ne...           257
# 9   https://www.yelp.com/biz/l-industrie-pizzeria-...           194
# 10  https://www.yelp.com/biz/pops-pizzas-new-york?...           213
# 11  https://www.yelp.com/biz/parla-new-york?adjust...            66
# 12  https://www.yelp.com/biz/brooklyn-pizza-master...           254
# 13  https://www.yelp.com/biz/l-industrie-pizzeria-...          1288
# 14  https://www.yelp.com/biz/lombardis-pizza-new-y...          6623
# 15  https://www.yelp.com/biz/lucia-of-soho-new-yor...            57
# 16  https://www.yelp.com/biz/norma-new-york-5?adju...           657
# 17  https://www.yelp.com/biz/pizzarte-new-york?adj...          1326
# 18  https://www.yelp.com/biz/andiamo-pizza-new-yor...           164
# 19  https://www.yelp.com/biz/donna-margherita-new-...           200
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 1              [{'alias': 'pizza', 'title': 'Pizza'}]     4.2
# 2              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.3
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     4.4
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     4.6
# 10             [{'alias': 'pizza', 'title': 'Pizza'}]     4.6
# 11  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.3
# 13             [{'alias': 'pizza', 'title': 'Pizza'}]     4.7
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     3.8
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.7
# 16  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.4
# 17  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.1
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 19  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.6
#
#                                           coordinates        transactions  \
# 0   {'latitude': 40.7608512, 'longitude': -73.9694...  [pickup, delivery]
# 1       {'latitude': 40.7547, 'longitude': -73.98696}  [pickup, delivery]
# 2   {'latitude': 40.7502059936523, 'longitude': -7...  [pickup, delivery]
# 3    {'latitude': 40.751211, 'longitude': -73.986364}  [pickup, delivery]
# 4      {'latitude': 40.75728, 'longitude': -73.97008}  [pickup, delivery]
# 5   {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 6    {'latitude': 40.778638, 'longitude': -73.952895}  [pickup, delivery]
# 7      {'latitude': 40.76492, 'longitude': -73.97794}  [pickup, delivery]
# 8      {'latitude': 40.75674, 'longitude': -73.96431}  [pickup, delivery]
# 9   {'latitude': 40.73323443774397, 'longitude': -...                  []
# 10   {'latitude': 40.767085, 'longitude': -73.983103}  [pickup, delivery]
# 11  {'latitude': 40.779604142118245, 'longitude': ...                  []
# 12  {'latitude': 40.75869828079016, 'longitude': -...  [pickup, delivery]
# 13     {'latitude': 40.71162, 'longitude': -73.95783}          [delivery]
# 14  {'latitude': 40.7215934960083, 'longitude': -7...  [pickup, delivery]
# 15  {'latitude': 40.721416405112784, 'longitude': ...  [pickup, delivery]
# 16   {'latitude': 40.743553, 'longitude': -73.980026}  [pickup, delivery]
# 17  {'latitude': 40.7629335072372, 'longitude': -7...  [pickup, delivery]
# 18   {'latitude': 40.746144, 'longitude': -73.990189}  [pickup, delivery]
# 19      {'latitude': 40.76652, 'longitude': -73.9598}  [pickup, delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '690 Lexington Ave', 'address2': ...  +12123171850
# 1      $  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 2     $$  {'address1': '413 8th Ave', 'address2': '', 'a...  +12125948939
# 3    NaN  {'address1': '980 6th Ave', 'address2': None, ...  +12124578555
# 4    NaN  {'address1': '163 E 52nd St', 'address2': '', ...  +16469520030
# 5      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 6    NaN  {'address1': '217 E 86th St', 'address2': None...  +16468612518
# 7     $$  {'address1': '117 W 57th St', 'address2': '', ...  +12123334333
# 8      $  {'address1': '989 1st Ave', 'address2': '', 'a...  +12128888816
# 9    NaN  {'address1': '104 Christopher St', 'address2':...  +12122560648
# 10     $  {'address1': '301 West 57th St', 'address2': '...  +12127848863
# 11   NaN  {'address1': '320 Columbus Ave', 'address2': '...  +12127029006
# 12   NaN  {'address1': '1055 1st Ave', 'address2': '', '...  +16466697757
# 13     $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 14    $$  {'address1': '32 Spring St', 'address2': '', '...  +12129417994
# 15   NaN  {'address1': '375 Canal St', 'address2': None,...  +19179652900
# 16    $$  {'address1': '438 3rd Ave', 'address2': None, ...  +12128890600
# 17    $$  {'address1': '69 W 55th St', 'address2': '', '...  +12122473936
# 18   NaN  {'address1': '818 6th Ave', 'address2': None, ...  +12122542860
# 19    $$  {'address1': '1304 2nd Ave', 'address2': 'Ste ...  +12127721169
#
#      display_phone     distance
# 0   (212) 317-1850   186.582143
# 1   (646) 559-4878  1552.864538
# 2   (212) 594-8939  2387.061955
# 3   (212) 457-8555  1669.751661
# 4   (646) 952-0030   210.615637
# 5   (212) 966-4100  4530.158358
# 6   (646) 861-2518  2577.937315
# 7   (212) 333-4333   949.977241
# 8   (212) 888-8816   520.331233
# 9   (212) 256-0648  4144.896542
# 10  (212) 784-8863  1440.059800
# 11  (212) 702-9006  2369.543702
# 12  (646) 669-7757   563.011393
# 13  (718) 599-0002  5382.969881
# 14  (212) 941-7994  4718.991458
# 15  (917) 965-2900  5120.936130
# 16  (212) 889-0600  1942.291384
# 17  (212) 247-3936   799.551320
# 18  (212) 254-2860  2263.112274
# 19  (212) 772-1169  1158.302440

# %%
# Save the API response as a JSON file
with open(JSON_FILE, 'w') as f:
    json.dump(results['businesses'], f)

# %%
# Read the JSON file into a DataFrame
df = pd.read_json(JSON_FILE)

# %%
# Looking at the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20 non-null     object
#  1   alias          20 non-null     object
#  2   name           20 non-null     object
#  3   image_url      20 non-null     object
#  4   is_closed      20 non-null     bool
#  5   url            20 non-null     object
#  6   review_count   20 non-null     int64
#  7   categories     20 non-null     object
#  8   rating         20 non-null     float64
#  9   coordinates    20 non-null     object
#  10  transactions   20 non-null     object
#  11  price          12 non-null     object
#  12  location       20 non-null     object
#  13  phone          20 non-null     int64
#  14  display_phone  20 non-null     object
#  15  distance       20 non-null     float64
# dtypes: bool(1), float64(2), int64(2), object(11)
# memory usage: 2.5+ KB

# %%
limit = 10

# %%
results = yelp.search_query(term=term, location='Queens', limit=1)
total_results = results['total']

# %%
limit = min(total_results, limit)

# %%
num_batches = (total_results // limit) + 1

# %%
all_results = []
for batch in range(num_batches):
    offset = batch * limit
    results = yelp.search_query(term=term, location=location, limit=limit, offset=offset, categories='pizza')
    all_results.extend(results['businesses'])
# Out:
# ---------------------------------------------------------------------------
# YelpAPIError                              Traceback (most recent call last)
# Cell In [24], line 4
#       2 for batch in range(num_batches):
#       3     offset = batch * limit
# ----> 4     results = yelp.search_query(term=term, location=location, limit=limit, offset=offset, categories='pizza')
#       5     all_results.extend(results['businesses'])
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\yelpapi\yelpapi.py:251, in YelpAPI.search_query(self, **kwargs)
#     247 if not kwargs.get('location') and (not kwargs.get('latitude') or not kwargs.get('longitude')):
#     248     raise ValueError('A valid location (parameter "location") or latitude/longitude combination '
#     249                      '(parameters "latitude" and "longitude") must be provided.')
# --> 251 return self._query(SEARCH_API_URL, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\yelpapi\yelpapi.py:299, in YelpAPI._query(self, url, **kwargs)
#     295 # Yelp can return one of many different API errors, so check for one of them.
#     296 # The Yelp Fusion API does not yet have a complete list of errors, but this is on the TODO list; see
#     297 # https://github.com/Yelp/yelp-fusion/issues/95 for more info.
#     298 if 'error' in response_json:
# --> 299     raise YelpAPI.YelpAPIError('{}: {}'.format(response_json['error']['code'],
#     300                                                response_json['error']['description']))
#     302 # we got a good response, so return
#     303 return response_json
#
# YelpAPIError: VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.

# %%
# Save all results to the JSON file
with open(JSON_FILE, 'w') as f:
    json.dump(all_results, f)

# %%
# Read the JSON file into a DataFrame
df = pd.read_json(JSON_FILE)
