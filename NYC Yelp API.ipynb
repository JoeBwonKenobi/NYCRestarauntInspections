# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Login Key
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'New York City'
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'New York City'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/New York City-Pizza.json already exists.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 12500

# %%
results['region']
# Out:
# {'center': {'longitude': -73.99429321289062, 'latitude': 40.70544486444615}}

# %%
results['region']
# Out:
# {'center': {'longitude': -73.99429321289062, 'latitude': 40.70544486444615}}

# %%
results['businesses']
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bckPg7Lznyf4rQSqvCJ2WA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5164,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1961.8771417367063},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/od36nFW220aMFAnNP00ocw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2740,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 308.56984360837544},
#  {'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1220,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 3145.016041338447},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrnhhj78RFiDhLIOUyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3253,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 1932.9467701334759},
#  {'id': 'G9hV4H2iGpWD8RoUpjtokg',
#   'alias': 'l-industrie-pizzeria-new-york',
#   'name': 'L’industrie Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_ClrWIn3hJDFbf5UR0vtMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 83,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.73323443774397, 'longitude': -74.0049081},
#   'transactions': [],
#   'location': {'address1': '104 Christopher St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['104 Christopher St', 'New York, NY 10014']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3216.943100434747},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IBr5ZEI3nJBCwHYxcg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 6620,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 1798.9959778083735},
#  {'id': 'uc5qQMzs96rzjK27epDCug',
#   'alias': 'joes-pizza-new-york-4',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FKjd9RGuNH-ixnd7AQxj0g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3094,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73060076, 'longitude': -74.00215997},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '7 Carmine St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7 Carmine St', 'New York, NY 10014']},
#   'phone': '+12123661182',
#   'display_phone': '(212) 366-1182',
#   'distance': 2874.702513677348},
#  {'id': 'hZBxJfZtDjnMzH_jNFNHRQ',
#   'alias': 'little-pizza-parlor-brooklyn',
#   'name': 'Little Pizza Parlor',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXQyfTZrmrJ3ra7nfPh4FQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-pizza-parlor-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 68,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.692425, 'longitude': -73.984467},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '192 Duffield St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['192 Duffield St', 'Brooklyn, NY 11201']},
#   'phone': '+13477991249',
#   'display_phone': '(347) 799-1249',
#   'distance': 1668.414103945315},
#  {'id': 'peV8B-MMMZb1mrC9r6rfAA',
#   'alias': 'lucia-of-soho-new-york',
#   'name': 'Lucia of Soho',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wO7d04A4mTpviADiKk10Yg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucia-of-soho-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 20,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.721416405112784, 'longitude': -74.0043748},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '375 Canal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['375 Canal St', 'New York, NY 10013']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1968.7604932148604},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FluVgKezP5ifs7greHV8Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2129,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 5508.746902433722},
#  {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#   'alias': 'scarrs-pizza-new-york',
#   'name': "Scarr's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xonxGJK91P_Ow3iY7olsxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 887,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7157238, 'longitude': -73.99161149999999},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '35 Orchard St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35 Orchard St', 'New York, NY 10002']},
#   'phone': '+12123343481',
#   'display_phone': '(212) 334-3481',
#   'distance': 1165.1002553888},
#  {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#   'alias': 'ny-pizza-suprema-new-york',
#   'name': 'NY Pizza Suprema',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2577,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7502059936523,
#    'longitude': -73.9953231811523},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'phone': '+12125948939',
#   'display_phone': '(212) 594-8939',
#   'distance': 4977.847939164096},
#  {'id': '6mYQzAdPxa4S1ZtvjST1eg',
#   'alias': 'julianas-time-out-market-brooklyn',
#   'name': "Juliana's - Time Out Market",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kqM6U4wGOhx1UtZtt2LMgA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-time-out-market-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 4,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.703447, 'longitude': -73.99215},
#   'transactions': [],
#   'location': {'address1': '55 Water St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Water St', 'Brooklyn, NY 11201']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 286.33958619941774},
#  {'id': '2ggi1luerd3Mf_C82JvCYg',
#   'alias': 'grimaldis-pizzeria-brooklyn-4',
#   'name': "Grimaldi's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-vwbIOY8hlTeWnrS74jQMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 4982,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7026459, 'longitude': -73.9932413},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188584300',
#   'display_phone': '(718) 858-4300',
#   'distance': 323.61541267581333},
#  {'id': 'EXQ0x2W9RTydIlHAU9MU1A',
#   'alias': 'mimis-pizza-new-york',
#   'name': "Mimi's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/btcWJW_uNq7JEwk2wFMtiQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mimis-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 173,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.778638, 'longitude': -73.952895},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '217 E 86th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['217 E 86th St', 'New York, NY 10028']},
#   'phone': '+16468612518',
#   'display_phone': '(646) 861-2518',
#   'distance': 8852.345604022003},
#  {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#   'alias': 'johns-of-bleecker-street-new-york-2',
#   'name': "John's of Bleecker Street",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Up7lhjRkQpl5PpmBQ0SFJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2700,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '278 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12122431680',
#   'display_phone': '(212) 243-1680',
#   'distance': 3010.899021476809},
#  {'id': 'vpkTNjq9dRh9rT3Nh0pe-A',
#   'alias': 'nolita-pizza-new-york-2',
#   'name': 'Nolita Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_BKVVoeQoEeYf0DjWcfArg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nolita-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 240,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7208883, 'longitude': -73.9962404},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '68 Kenmare St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['68 Kenmare St', 'New York, NY 10012']},
#   'phone': '+16468959131',
#   'display_phone': '(646) 895-9131',
#   'distance': 1725.0543086810944},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0WEXB_9LUY86MTKnc2UXug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 467,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7168952, 'longitude': -73.95892996733771},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 3241.190355020982},
#  {'id': '16ZnHpuaaBt92XWeJHCC5A',
#   'alias': 'olio-e-più-new-york-7',
#   'name': 'Olio e Più',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz_Q4QBHxxxxDJJTTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olio-e-pi%C3%B9-new-york-7?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5162,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.733798036104304,
#    'longitude': -73.99977392649927},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3 Greenwich Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#   'phone': '+12122436546',
#   'display_phone': '(212) 243-6546',
#   'distance': 3186.3804982206075},
#  {'id': '4h4Tuuc56YPO6lWfZ1bdSQ',
#   'alias': 'joes-pizza-new-york-152',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sUjegcIlz9bo1s20BqM5KA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 544,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7101297729083,
#    'longitude': -74.0077206864953},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '124 Fulton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['124 Fulton St', 'New York, NY 10038']},
#   'phone': '+12122670860',
#   'display_phone': '(212) 267-0860',
#   'distance': 1245.9428626945232}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                
# 13  https://www.yelp.com/biz/grimaldis-pizzeria-br...          4982
# 14  https://www.yelp.com/biz/mimis-pizza-new-york?...           173
# 15  https://www.yelp.com/biz/johns-of-bleecker-str...          2700
# 16  https://www.yelp.com/biz/nolita-pizza-new-york...           240
# 17  https://www.yelp.com/biz/joes-pizza-brooklyn-8...           467
# 18  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          5162
# 19  https://www.yelp.com/biz/joes-pizza-new-york-1...           544
#
#                                            categories  rating  \
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 10             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 12             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 1   {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 2      {'latitude': 40.71162, 'longitude': -73.95783}  [pickup, delivery]
# 3    {'latitude': 40.722766, 'longitude': -73.996233}            [pickup]
# 4   {'latitude': 40.73323443774397, 'longitude': -...                  []
# 5   {'latitude': 40.7215934960083, 'longitude': -7...  [pickup, delivery]
# 6   {'latitude': 40.73060076, 'longitude': -74.002...          [delivery]
# 7    {'latitude': 40.692425, 'longitude': -73.984467}  [pickup, delivery]
# 8   {'latitude': 40.721416405112784, 'longitude': ...  [pickup, delivery]
# 9       {'latitude': 40.7547, 'longitude': -73.98696}  [pickup, delivery]
# 10  {'latitude': 40.7157238, 'longitude': -73.9916...  [pickup, delivery]
# 11  {'latitude': 40.7502059936523, 'longitude': -7...  [pickup, delivery]
# 12    {'latitude': 40.703447, 'longitude': -73.99215}                  []
# 13  {'latitude': 40.7026459, 'longitude': -73.9932...  [pickup, delivery]
# 14   {'latitude': 40.778638, 'longitude': -73.952895}  [pickup, delivery]
# 15     {'latitude': 40.73158, 'longitude': -74.00332}  [pickup, delivery]
# 16  {'latitude': 40.7208883, 'longitude': -73.9962...  [pickup, delivery]
# 17  {'latitude': 40.7168952, 'longitude': -73.9589...  [pickup, delivery]
# 18  {'latitude': 40.733798036104304, 'longitude': ...  [pickup, delivery]
# 19  {'latitude': 40.7101297729083, 'longitude': -7...  [pickup, delivery]
#
#    price                                           location         phone  \
# 0      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1     $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 2      $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 3     $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
# 4    NaN  {'address1': '104 Christopher St', 'address2':...
# 5     $$  {'address1': '32 Spring St', 'address2': '', '...  +12129417994
# 6      $  {'address1': '7 Carmine St', 'address2': '', '...  +12123661182
# 7    NaN  {'address1': '192 Duffield St', 'address2': No...  +13477991249
# 8    NaN  {'address1': '375 Canal St', 'address2': None,...
# 9      $  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 10     $  {'address1': '35 Orchard St', 'address2': '', ...  +12123343481
# 11     $  {'address1': '413 8th Ave', 'address2': '', 'a...  +12125948939
# 12   NaN  {'address1': '55 Water St', 'address2': '', 'a...
# 13    $$  {'address1': '1 Front St', 'address2': '', 'ad...  +17188584300
# 14   NaN  {'address1': '217 E 86th St', 'address2': None...  +16468612518
# 15    $$  {'address1': '278 Bleecker St', 'address2': ''...  +12122431680
# 16     $  {'address1': '68 Kenmare St', 'address2': None...  +16468959131
# 17     $  {'address1': '216 Bedford Ave', 'address2': ''...  +17183882216
# 18    $$  {'address1': '3 Greenwich Ave', 'address2': No...  +12122436546
# 19     $  {'address1': '124 Fulton St', 'address2': '', ...  +12122670860
#
#      display_phone     distance
# 0   (212) 966-4100  1961.877142
# 1   (718) 596-6700   308.569844
# 2   (718) 599-0002  3145.016041
# 3   (212) 965-0500  1932.946770
# 4                   3216.943100
# 5   (212) 941-7994  1798.995978
# 6   (212) 366-1182  2874.702514
# 7   (347) 799-1249  1668.414104
# 8                   1968.760493
# 9   (646) 559-4878  5508.746902
# 10  (212) 334-3481  1165.100255
# 11  (212) 594-8939  4977.847939
# 12                   286.339586
# 13  (718) 858-4300   323.615413
# 14  (646) 861-2518  8852.345604
# 15  (212) 243-1680  3010.899021
# 16  (646) 895-9131  1725.054309
# 17  (718) 388-2216  3241.190355
# 18  (212) 243-6546  3186.380498
# 19  (212) 267-0860  1245.942863

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 results.JSON_FILE()
#
# AttributeError: 'dict' object has no attribute 'JSON_FILE'

# %%
# Converting the JSON file to a dataframe
df = pd.read_json(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 2
#       1 # Converting the JSON file to a dataframe
# ----> 2 df = pd.read_json(results)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\json\_json.py:733, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     730 if convert_axes is None and orient != "table":
#     731     convert_axes = True
# --> 733 json_reader = JsonReader(
#     734     path_or_buf,
#     735     orient=orient,
#     736     typ=typ,
#     737     dtype=dtype,
#     738     convert_axes=convert_axes,
#     739     convert_dates=convert_dates,
#     740     keep_default_dates=keep_default_dates,
#     741     numpy=numpy,
#     742     precise_float=precise_float,
#     743     date_unit=date_unit,
#     744     encoding=encoding,
#     745     lines=lines,
#     746     chunksize=chunksize,
#     747     compression=compression,
#     748     nrows=nrows,
#     749     storage_options=storage_options,
#     750     encoding_errors=encoding_errors,
#     751 )
#     753 if chunksize:
#     754     return json_reader
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\json\_json.py:818, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     815     if not self.lines:
#     816         raise ValueError("nrows can only be passed if lines=True")
# --> 818 data = self._get_data_from_filepath(filepath_or_buffer)
#     819 self.data = self._preprocess_data(data)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\json\_json.py:858, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     851 filepath_or_buffer = stringify_path(filepath_or_buffer)
#     852 if (
#     853     not isinstance(filepath_or_buffer, str)
#     854     or is_url(filepath_or_buffer)
#     855     or is_fsspec_url(filepath_or_buffer)
#     856     or file_exists(filepath_or_buffer)
#     857 ):
# --> 858     self.handles = get_handle(
#     859         filepath_or_buffer,
#     860         "r",
#     861         encoding=self.encoding,
#     862         compression=self.compression,
#     863         storage_options=self.storage_options,
#     864         errors=self.encoding_errors,
#     865     )
#     866     filepath_or_buffer = self.handles.handle
#     867 elif (
#     868     isinstance(filepath_or_buffer, str)
#     869     and filepath_or_buffer.lower().endswith(
#    (...)
#     872     and not file_exists(filepath_or_buffer)
#     873 ):
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\common.py:713, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     710     codecs.lookup_error(errors)
#     712 # open URLs
# --> 713 ioargs = _get_filepath_or_buffer(
#     714     path_or_buf,
#     715     encoding=encoding,
#     716     compression=compression,
#     717     mode=mode,
#     718     storage_options=storage_options,
#     719 )
#     721 handle = ioargs.filepath_or_buffer
#     722 handles: list[BaseBuffer]
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\common.py:451, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     447 if not (
#     448     hasattr(filepath_or_buffer, "read") or hasattr(filepath_or_buffer, "write")
#     449 ):
#     450     msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 451     raise ValueError(msg)
#     453 return IOArgs(
#     454     filepath_or_buffer=filepath_or_buffer,
#     455     encoding=encoding,
#    (...)
#     458     mode=mode,
#     459 )
#
# ValueError: Invalid file path or buffer object type: <class 'dict'>

# %%
# Looking at the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 0 entries
# Empty DataFrame
