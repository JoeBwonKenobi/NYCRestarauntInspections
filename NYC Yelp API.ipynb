# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Login Key
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'Manhattan'
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'Manhattan'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Manhattan-Pizza.json not found. Saving empty list to file.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 8800

# %%
results['region']
# Out:
# {'center': {'longitude': -73.96957397460938, 'latitude': 40.75917470627005}}

# %%
results['businesses']
# Out:
# [{'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FluVgKezP5ifs7greHV8Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2131,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 1552.86453787486},
#  {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#   'alias': 'my-pie-pizzeria-romana-new-york-2',
#   'name': 'My Pie Pizzeria Romana',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gYzrw_hwa4sugXSjLOcePA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 923,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '690 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#   'phone': '+12123171850',
#   'display_phone': '(212) 317-1850',
#   'distance': 186.58214310058082},
#  {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#   'alias': 'ny-pizza-suprema-new-york',
#   'name': 'NY Pizza Suprema',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 2578,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7502059936523,
#    'longitude': -73.9953231811523},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'phone': '+12125948939',
#   'display_phone': '(212) 594-8939',
#   'distance': 2387.061954989499},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bckPg7Lznyf4rQSqvCJ2WA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5166,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 4530.158358332591},
#  {'id': 'YchMTqpM6xksrpqXR0YUrQ',
#   'alias': 'xeno-s-pizza-new-york',
#   'name': 'Xeno’s Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dVkXWNvDYPgZ7OesI246Kw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/xeno-s-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 26,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75728, 'longitude': -73.97008},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '163 E 52nd St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['163 E 52nd St', 'New York, NY 10022']},
#   'phone': '+16469520030',
#   'display_phone': '(646) 952-0030',
#   'distance': 210.61563672529866},
#  {'id': 'tRIHhPKryUZ56SfIz6mLiA',
#   'alias': 'angelos-coal-oven-pizzeria-new-york',
#   'name': "Angelo's Coal Oven Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_DsPiET9EnikFNy-AvoVxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/angelos-coal-oven-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1244,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76492, 'longitude': -73.97794},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '117 W 57th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['117 W 57th St', 'New York, NY 10019']},
#   'phone': '+12123334333',
#   'display_phone': '(212) 333-4333',
#   'distance': 949.9772407230507},
#  {'id': 'EXQ0x2W9RTydIlHAU9MU1A',
#   'alias': 'mimis-pizza-new-york',
#   'name': "Mimi's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/btcWJW_uNq7JEwk2wFMtiQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mimis-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 173,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.778638, 'longitude': -73.952895},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '217 E 86th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['217 E 86th St', 'New York, NY 10028']},
#   'phone': '+16468612518',
#   'display_phone': '(646) 861-2518',
#   'distance': 2577.9373154983723},
#  {'id': 'KEgdfVEVVgJFnGFiLNPDzQ',
#   'alias': 'sofia-pizza-shoppe-new-york',
#   'name': 'Sofia Pizza Shoppe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rLGuKKkY5apq7CqG1z3Q6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sofia-pizza-shoppe-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 251,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75674, 'longitude': -73.96431},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '989 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['989 1st Ave', 'New York, NY 10022']},
#   'phone': '+12128888816',
#   'display_phone': '(212) 888-8816',
#   'distance': 520.3312331060953},
#  {'id': 'V4-ds3mhlB7uLLY9qfZTJQ',
#   'alias': 'abitinos-pizzeria-new-york-17',
#   'name': "Abitino's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AKoSCHLZUHbiVXHdiN_8gQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/abitinos-pizzeria-new-york-17?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 34,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75958, 'longitude': -73.97747},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '5 West 51 St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10020',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['5 West 51 St', 'New York, NY 10020']},
#   'phone': '+12123566181',
#   'display_phone': '(212) 356-6181',
#   'distance': 667.90284054447},
#  {'id': 'GgdR6L49eKH5drPaOYOOPQ',
#   'alias': 'pops-pizzas-new-york',
#   'name': "Pop's Pizzas",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K51H3tN_XFj8LCYv5raNWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pops-pizzas-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 198,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.767086, 'longitude': -73.983033},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '301 West 57th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['301 West 57th St', 'New York, NY 10019']},
#   'phone': '+12127848863',
#   'display_phone': '(212) 784-8863',
#   'distance': 1440.2080877869132},
#  {'id': 'AOZlppihRNG8Y2N4Jid30A',
#   'alias': 'brooklyn-pizza-masters-new-york',
#   'name': 'Brooklyn Pizza Masters',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Dko2ofSegIWoF3n57Y5ISQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyn-pizza-masters-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 246,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75869828079016,
#    'longitude': -73.962919097227},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1055 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1055 1st Ave', 'New York, NY 10022']},
#   'phone': '+16466697757',
#   'display_phone': '(646) 669-7757',
#   'distance': 563.0113927421821},
#  {'id': 'kVVjtVwlKwxKp4E345sdIw',
#   'alias': 'goodfellas-pizzeria-of-lic-long-island-city-2',
#   'name': 'Goodfellas Pizzeria of LIC',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/thGonacC2LZUXqVNnB9Wpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/goodfellas-pizzeria-of-lic-long-island-city-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 89,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75341267837556,
#    'longitude': -73.93712752116163},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '25-19 40th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Long Island City',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['25-19 40th Ave', 'Long Island City, NY 11101']},
#   'phone': '+17184721932',
#   'display_phone': '(718) 472-1932',
#   'distance': 2807.041362300401},
#  {'id': 'UB1mGugr1pvgUUP1eTNXrg',
#   'alias': 'stone-bridge-pizza-and-salad-new-york',
#   'name': 'Stone Bridge Pizza & Salad',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yfY3OA1Zd1GWBnbeZoWB8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/stone-bridge-pizza-and-salad-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 337,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.75225, 'longitude': -73.98061},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '16 E 41st St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['16 E 41st St', 'New York, NY 10017']},
#   'phone': '+16467915690',
#   'display_phone': '(646) 791-5690',
#   'distance': 1207.7148971914448},
#  {'id': 'G9hV4H2iGpWD8RoUpjtokg',
#   'alias': 'l-industrie-pizzeria-new-york',
#   'name': 'L’industrie Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_ClrWIn3hJDFbf5UR0vtMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 84,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.73323443774397, 'longitude': -74.0049081},
#   'transactions': [],
#   'location': {'address1': '104 Christopher St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['104 Christopher St', 'New York, NY 10014']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 4144.896541579684},
#  {'id': 'xsQTIeq-WLkp4ParkTQpMQ',
#   'alias': 'pizzarte-new-york',
#   'name': 'PizzArte',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FD2amDUAhuqIyRcd_S7d-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzarte-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1316,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7629335072372,
#    'longitude': -73.9776668697596},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '69 W 55th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 W 55th St', 'New York, NY 10019']},
#   'phone': '+12122473936',
#   'display_phone': '(212) 247-3936',
#   'distance': 799.5513204887},
#  {'id': '2-GsvFaQpVpbaIdwb9lSeQ',
#   'alias': 'andiamo-pizza-new-york-2',
#   'name': 'Andiamo Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0SPjEd6UA3mn5ZJqLMt7LA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/andiamo-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 133,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.746144, 'longitude': -73.990189},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '818 6th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['818 6th Ave', 'New York, NY 10001']},
#   'phone': '+12122542860',
#   'display_phone': '(212) 254-2860',
#   'distance': 2263.1122742182406},
#  {'id': 'DCiEo7qucPaEj7Gtdj1U9A',
#   'alias': 'sant-ambroeus-new-york',
#   'name': 'Sant Ambroeus',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7B4Ntnr-UGLiowyhJ4U2vA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sant-ambroeus-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 526,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.77541, 'longitude': -73.96297},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1000 Madison Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10075',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1000 Madison Ave', 'New York, NY 10075']},
#   'phone': '+12125702211',
#   'display_phone': '(212) 570-2211',
#   'distance': 1889.8707765669067},
#  {'id': 'S4ZgNfuLH2i0ScdaxaHg3w',
#   'alias': 'uncle-vinny-s-pizza-new-york',
#   'name': 'Uncle Vinny’s Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gGX4aGkjRXIA31rVHMfLlw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/uncle-vinny-s-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 13,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.761795, 'longitude': -73.96008},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1140 1st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10065',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1140 1st Ave', 'New York, NY 10065']},
#   'phone': '+12128385080',
#   'display_phone': '(212) 838-5080',
#   'distance': 854.6798299228852},
#  {'id': '2MuvmwOuwvGOWkBimhniLA',
#   'alias': 'la-bellezza-new-york',
#   'name': 'La Bellezza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/75SVEMwv8WbLIB4eYzPdLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-bellezza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 309,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7557792663574,
#    'longitude': -73.9720153808594},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '145 E 49th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['145 E 49th St', 'New York, NY 10017']},
#   'phone': '+12128713223',
#   'display_phone': '(212) 871-3223',
#   'distance': 426.901060768092},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrnhhj78RFiDhLIOUyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3258,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 4629.739253785127}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                          alias  \
# 0   KEEXuHCYhsQJ-zpJhu98bA                        joes-pizza-new-york-148
# 1   oRdM7n-AfBPBGAlH4Q0Sag              my-pie-pizzeria-romana-new-york-2
# 2   -9NO2IDCJMyNGZMAQ1-VQw                      ny-pizza-suprema-new-york
# 3   zj8Lq1T8KIC5zwFief15jg                 prince-street-pizza-new-york-2
# 4   YchMTqpM6xksrpqXR0YUrQ                          xeno-s-pizza-new-york
# 5   tRIHhPKryUZ56SfIz6mLiA            angelos-coal-oven-pizzeria-new-york
# 6   EXQ0x2W9RTydIlHAU9MU1A                           mimis-pizza-new-york
# 7   KEgdfVEVVgJFnGFiLNPDzQ                    sofia-pizza-shoppe-new-york
# 8   V4-ds3mhlB7uLLY9qfZTJQ                  abitinos-pizzeria-new-york-17
# 9   GgdR6L49eKH5drPaOYOOPQ                           pops-pizzas-new-york
# 10  AOZlppihRNG8Y2N4Jid30A                brooklyn-pizza-masters-new-york
# 11  kVVjtVwlKwxKp4E345sdIw  goodfellas-pizzeria-of-lic-long-island-city-2
# 12  UB1mGugr1pvgUUP1eTNXrg          stone-bridge-pizza-and-salad-new-york
# 13  G9hV4H2iGpWD8RoUpjtokg                  l-industrie-pizzeria-new-york
# 14  xsQTIeq-WLkp4ParkTQpMQ                              pizzarte-new-york
# 15  2-GsvFaQpVpbaIdwb9lSeQ                       andiamo-pizza-new-york-2
# 16  DCiEo7qucPaEj7Gtdj1U9A                         sant-ambroeus-new-york
# 17  S4ZgNfuLH2i0ScdaxaHg3w                   uncle-vinny-s-pizza-new-york
# 18  2MuvmwOuwvGOWkBimhniLA                           la-bellezza-new-york
# 19  WG639VkTjmK5dzydd1BBJA                            rubirosa-new-york-2
#
#                            name  \
# 0                   Joe's Pizza
# 1        My Pie Pizzeria Romana
# 2              NY Pizza Suprema
# 3           Prince Street Pizza
# 4                  Xeno’s Pizza
# 5   Angelo's Coal Oven Pizzeria
# 6                  Mimi's Pizza
# 7            Sofia Pizza Shoppe
# 8            Abitino's Pizzeria
# 9                  Pop's Pizzas
# 10       Brooklyn Pizza Masters
# 11   Goodfellas Pizzeria of LIC
# 12   Stone Bridge Pizza & Salad
# 13         L’industrie Pizzeria
# 14                     PizzArte
# 15                Andiamo Pizza
# 16                Sant Ambroeus
# 17          Uncle Vinny’s Pizza
# 18                  La Bellezza
# 19                     Rubirosa
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/FluVgK...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/gYzrw_...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXn...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/bckPg7...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/dVkXWN...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/_DsPiE...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/btcWJW...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/rLGuKK...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/AKoSCH...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/K51H3t...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/Dko2of...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/thGona...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/yfY3OA...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/_ClrWI...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/FD2amD...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/0SPjEd...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/7B4Ntn...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/gGX4aG...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/75SVEM...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrn...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/joes-pizza-new-york-1...          2131
# 1   https://www.yelp.com/biz/my-pie-pizzeria-roman...           923
# 2   https://www.yelp.com/biz/ny-pizza-suprema-new-...          2578
# 3   https://www.yelp.com/biz/prince-street-pizza-n...          5166
# 4   https://www.yelp.com/biz/xeno-s-pizza-new-york...            26
# 5   https://www.yelp.com/biz/angelos-coal-oven-piz...          1244
# 6   https://www.yelp.com/biz/mimis-pizza-new-york?...           173
# 7   https://www.yelp.com/biz/sofia-pizza-shoppe-ne...           251
# 8   https://www.yelp.com/biz/abitinos-pizzeria-new...            34
# 9   https://www.yelp.com/biz/pops-pizzas-new-york?...           198
# 10  https://www.yelp.com/biz/brooklyn-pizza-master...           246
# 11  https://www.yelp.com/biz/goodfellas-pizzeria-o...            89
# 12  https://www.yelp.com/biz/stone-bridge-pizza-an...           337
# 13  https://www.yelp.com/biz/l-industrie-pizzeria-...            84
# 14  https://www.yelp.com/biz/pizzarte-new-york?adj...          1316
# 15  https://www.yelp.com/biz/andiamo-pizza-new-yor...           133
# 16  https://www.yelp.com/biz/sant-ambroeus-new-yor...           526
# 17  https://www.yelp.com/biz/uncle-vinny-s-pizza-n...            13
# 18  https://www.yelp.com/biz/la-bellezza-new-york?...           309
# 19  https://www.yelp.com/biz/rubirosa-new-york-2?a...          3258
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 5   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 7              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 13             [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 14  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 16  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 18             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 19  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
#
#                                           coordinates        transactions  \
# 0       {'latitude': 40.7547, 'longitude': -73.98696}  [pickup, delivery]
# 1   {'latitude': 40.7608512, 'longitude': -73.9694...  [pickup, delivery]
# 2   {'latitude': 40.7502059936523, 'longitude': -7...  [pickup, delivery]
# 3   {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 4      {'latitude': 40.75728, 'longitude': -73.97008}  [pickup, delivery]
# 5      {'latitude': 40.76492, 'longitude': -73.97794}  [pickup, delivery]
# 6    {'latitude': 40.778638, 'longitude': -73.952895}  [pickup, delivery]
# 7      {'latitude': 40.75674, 'longitude': -73.96431}  [pickup, delivery]
# 8      {'latitude': 40.75958, 'longitude': -73.97747}  [pickup, delivery]
# 9    {'latitude': 40.767086, 'longitude': -73.983033}  [pickup, delivery]
# 10  {'latitude': 40.75869828079016, 'longitude': -...  [pickup, delivery]
# 11  {'latitude': 40.75341267837556, 'longitude': -...          [delivery]
# 12     {'latitude': 40.75225, 'longitude': -73.98061}  [pickup, delivery]
# 13  {'latitude': 40.73323443774397, 'longitude': -...                  []
# 14  {'latitude': 40.7629335072372, 'longitude': -7...  [delivery, pickup]
# 15   {'latitude': 40.746144, 'longitude': -73.990189}  [pickup, delivery]
# 16     {'latitude': 40.77541, 'longitude': -73.96297}          [delivery]
# 17    {'latitude': 40.761795, 'longitude': -73.96008}  [pickup, delivery]
# 18  {'latitude': 40.7557792663574, 'longitude': -7...  [pickup, delivery]
# 19   {'latitude': 40.722766, 'longitude': -73.996233}            [pickup]
#
#    price                                           location         phone  \
# 0      $  {'address1': '1435 Broadway', 'address2': '', ...  +16465594878
# 1     $$  {'address1': '690 Lexington Ave', 'address2': ...  +12123171850
# 2      $  {'address1': '413 8th Ave', 'address2': '', 'a...  +12125948939
# 3      $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 4    NaN  {'address1': '163 E 52nd St', 'address2': '', ...  +16469520030
# 5     $$  {'address1': '117 W 57th St', 'address2': '', ...  +12123334333
# 6    NaN  {'address1': '217 E 86th St', 'address2': None...  +16468612518
# 7      $  {'address1': '989 1st Ave', 'address2': '', 'a...  +12128888816
# 8    NaN  {'address1': '5 West 51 St', 'address2': None,...  +12123566181
# 9      $  {'address1': '301 West 57th St', 'address2': N...  +12127848863
# 10   NaN  {'address1': '1055 1st Ave', 'address2': '', '...  +16466697757
# 11     $  {'address1': '25-19 40th Ave', 'address2': '',...  +17184721932
# 12    $$  {'address1': '16 E 41st St', 'address2': None,...  +16467915690
# 13   NaN  {'address1': '104 Christopher St', 'address2':...
# 14    $$  {'address1': '69 W 55th St', 'address2': '', '...  +12122473936
# 15   NaN  {'address1': '818 6th Ave', 'address2': None, ...  +12122542860
# 16   $$$  {'address1': '1000 Madison Ave', 'address2': N...  +12125702211
# 17   NaN  {'address1': '1140 1st Ave', 'address2': None,...  +12128385080
# 18     $  {'address1': '145 E 49th St', 'address2': '', ...  +12128713223
# 19    $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
#
#      display_phone     distance
# 0   (646) 559-4878  1552.864538
# 1   (212) 317-1850   186.582143
# 2   (212) 594-8939  2387.061955
# 3   (212) 966-4100  4530.158358
# 4   (646) 952-0030   210.615637
# 5   (212) 333-4333   949.977241
# 6   (646) 861-2518  2577.937315
# 7   (212) 888-8816   520.331233
# 8   (212) 356-6181   667.902841
# 9   (212) 784-8863  1440.208088
# 10  (646) 669-7757   563.011393
# 11  (718) 472-1932  2807.041362
# 12  (646) 791-5690  1207.714897
# 13                  4144.896542
# 14  (212) 247-3936   799.551320
# 15  (212) 254-2860  2263.112274
# 16  (212) 570-2211  1889.870777
# 17  (212) 838-5080   854.679830
# 18  (212) 871-3223   426.901061
# 19  (212) 965-0500  4629.739254

# %%
# Save the API response as a JSON file
with open(JSON_FILE, 'w') as f:
    json.dump(results['businesses'], f)

# %%
# Read the JSON file into a DataFrame
df = pd.read_json(JSON_FILE)

# %%
# Looking at the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20 non-null     object
#  1   alias          20 non-null     object
#  2   name           20 non-null     object
#  3   image_url      20 non-null     object
#  4   is_closed      20 non-null     bool
#  5   url            20 non-null     object
#  6   review_count   20 non-null     int64
#  7   categories     20 non-null     object
#  8   rating         20 non-null     float64
#  9   coordinates    20 non-null     object
#  10  transactions   20 non-null     object
#  11  price          13 non-null     object
#  12  location       20 non-null     object
#  13  phone          20 non-null     object
#  14  display_phone  20 non-null     object
#  15  distance       20 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 2.5+ KB

# %%
limit = 10

# %%
results = yelp.search_query(term=term, location='Queens', limit=1)
total_results = results['total']

# %%
limit = min(total_results, limit)

# %%
num_batches = (total_results // limit) + 1

# %%
all_results = []
for batch in range(num_batches):
    offset = batch * limit
    results = yelp.search_query(term=term, location=location, limit=limit, offset=offset, categories='pizza')
    all_results.extend(results['businesses'])
# Out:
# ---------------------------------------------------------------------------
# YelpAPIError                              Traceback (most recent call last)
# Cell In [24], line 4
#       2 for batch in range(num_batches):
#       3     offset = batch * limit
# ----> 4     results = yelp.search_query(term=term, location=location, limit=limit, offset=offset, categories='pizza')
#       5     all_results.extend(results['businesses'])
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\yelpapi\yelpapi.py:251, in YelpAPI.search_query(self, **kwargs)
#     247 if not kwargs.get('location') and (not kwargs.get('latitude') or not kwargs.get('longitude')):
#     248     raise ValueError('A valid location (parameter "location") or latitude/longitude combination '
#     249                      '(parameters "latitude" and "longitude") must be provided.')
# --> 251 return self._query(SEARCH_API_URL, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\yelpapi\yelpapi.py:299, in YelpAPI._query(self, url, **kwargs)
#     295 # Yelp can return one of many different API errors, so check for one of them.
#     296 # The Yelp Fusion API does not yet have a complete list of errors, but this is on the TODO list; see
#     297 # https://github.com/Yelp/yelp-fusion/issues/95 for more info.
#     298 if 'error' in response_json:
# --> 299     raise YelpAPI.YelpAPIError('{}: {}'.format(response_json['error']['code'],
#     300                                                response_json['error']['description']))
#     302 # we got a good response, so return
#     303 return response_json
#
# YelpAPIError: VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.

# %%
# Save all results to the JSON file
with open(JSON_FILE, 'w') as f:
    json.dump(all_results, f)

# %%
# Read the JSON file into a DataFrame
df = pd.read_json(JSON_FILE)
