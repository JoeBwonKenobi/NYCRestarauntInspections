# %% [markdown]
# # **NYC Restaurant YELP API**

# %% [markdown]
# Joseph Lardie
#
# December 2023

# %% [markdown]
# # **Imports**

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # **Calling API**

# %%
# Load API Credentials
with open('/Users/davyd/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Login Key
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %% [markdown]
# # **Defining Search Parameters**

# %%
# set our API call parameters and filename before the first call
location = 'New York, NY 10009'
term = 'Pizza'

# %%
location.split(',')[0]
# Out:
# 'New York'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/New York-Pizza.json not found. Saving empty list to file.

# %%
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 1400

# %%
results['region']
# Out:
# {'center': {'longitude': -73.97995948791504, 'latitude': 40.72677021626302}}

# %%
results['businesses']
# Out:
# [{'id': 'oOr6Ta5gZyDl6PyZ1cq7pg',
#   'alias': 'east-village-pizza-new-york',
#   'name': 'East Village Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KOrE1ez2CtKZ44Un7EFaTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/east-village-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 531,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.728212, 'longitude': -73.985182},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '145 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['145 1st Ave', 'New York, NY 10003']},
#   'phone': '+12125294545',
#   'display_phone': '(212) 529-4545',
#   'distance': 469.92936068672833},
#  {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#   'alias': 'village-square-pizza-new-york-3',
#   'name': 'Village Square Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gFPiIHKfxpoinyOQWoMnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 299,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '147 Ave A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['147 Ave A', 'New York, NY 10009']},
#   'phone': '+19176757709',
#   'display_phone': '(917) 675-7709',
#   'distance': 249.4757294754748},
#  {'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bckPg7Lznyf4rQSqvCJ2WA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 5156,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1294.3281460482128},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrnhhj78RFiDhLIOUyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3242,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 1441.826860285314},
#  {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#   'alias': 'joes-pizza-new-york-7',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QXu6RGXGrtRWssVmFE7KpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1083,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '150 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 E 14th St', 'New York, NY 10003']},
#   'phone': '+12123889474',
#   'display_phone': '(212) 388-9474',
#   'distance': 968.5860971975771},
#  {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#   'alias': 'artichoke-basilles-pizza-new-york-2',
#   'name': "Artichoke Basille's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4krjwPml7pLVDnn56sf6AQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 4217,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73216, 'longitude': -73.983877},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '321 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['321 E 14th St', 'New York, NY 10003']},
#   'phone': '+12122282004',
#   'display_phone': '(212) 228-2004',
#   'distance': 684.947758824856},
#  {'id': 'GyN4Kl0vFwziRN-h-Ow7ig',
#   'alias': 'saint-pizza-new-york',
#   'name': 'Saint Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6gTOBJcMgeW_-oPp08WEMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/saint-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 16,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72905715251202,
#    'longitude': -73.97811846649704},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '223 Avenue B',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['223 Avenue B', 'New York, NY 10009']},
#   'phone': '+16463988250',
#   'display_phone': '(646) 398-8250',
#   'distance': 297.8804615541635},
#  {'id': 'TWH4MjLtN1fKlF-7n6YXHg',
#   'alias': 'lil-frankies-new-york',
#   'name': "Lil Frankie's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t0OsEVlzDWgM_NMGVHmPiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lil-frankies-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1515,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.723625, 'longitude': -73.988555},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '19 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 1st Ave', 'New York, NY 10003']},
#   'phone': '+12124204900',
#   'display_phone': '(212) 420-4900',
#   'distance': 795.5918291487195},
#  {'id': 'ow-zOxbslAoVw_uZ5UYoOA',
#   'alias': 'chrissy-s-pizza-new-york',
#   'name': 'Chrissy’s Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CPG7WcRezxMVh8PjedTWmw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chrissy-s-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.72742, 'longitude': -73.983531},
#   'transactions': [],
#   'location': {'address1': '430 E 9th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['430 E 9th St', 'New York, NY 10009']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 317.8002474945234},
#  {'id': 'uc5qQMzs96rzjK27epDCug',
#   'alias': 'joes-pizza-new-york-4',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FKjd9RGuNH-ixnd7AQxj0g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 3096,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73060076, 'longitude': -74.00215997},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '7 Carmine St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7 Carmine St', 'New York, NY 10014']},
#   'phone': '+12123661182',
#   'display_phone': '(212) 366-1182',
#   'distance': 1918.5852692904334},
#  {'id': 'MeQU-nGaQvX12VXYOyzavQ',
#   'alias': 'gruppo-nycthincrust-pizza-new-york',
#   'name': 'GRUPPO NYCThinCrust Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4fE7bGFzZ_DioRIQNyvCag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gruppo-nycthincrust-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 278,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '98 Ave  B',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['98 Ave  B', 'New York, NY 10009']},
#   'phone': '+12129952100',
#   'display_phone': '(212) 995-2100',
#   'distance': 267.1822952825941},
#  {'id': 'peV8B-MMMZb1mrC9r6rfAA',
#   'alias': 'lucia-of-soho-new-york',
#   'name': 'Lucia of Soho',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wO7d04A4mTpviADiKk10Yg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucia-of-soho-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 19,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.721416405112784, 'longitude': -74.0043748},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '375 Canal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['375 Canal St', 'New York, NY 10013']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2141.874944447376},
#  {'id': 'vpkTNjq9dRh9rT3Nh0pe-A',
#   'alias': 'nolita-pizza-new-york-2',
#   'name': 'Nolita Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_BKVVoeQoEeYf0DjWcfArg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nolita-pizza-new-york-2?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 238,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7208883, 'longitude': -73.9962404},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '68 Kenmare St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['68 Kenmare St', 'New York, NY 10012']},
#   'phone': '+16468959131',
#   'display_phone': '(646) 895-9131',
#   'distance': 1519.917462771413},
#  {'id': 'ss0D4of03oe4SPsILObmNg',
#   'alias': 'potenza-centrale-pizza-new-york',
#   'name': 'Potenza Centrale Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zH0HoPCs0jPI_euJ9BT2GA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/potenza-centrale-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 6,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.72291908527927,
#    'longitude': -73.98298298944482},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '38 Avenue B',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['38 Avenue B', 'New York, NY 10009']},
#   'phone': '+16468526995',
#   'display_phone': '(646) 852-6995',
#   'distance': 498.29124891045535},
#  {'id': '0ROpM3UcZhprN6dhwK2Hsw',
#   'alias': 'joe-and-pats-pizzeria-new-york',
#   'name': "Joe & Pat's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bvllEgvnc76ZTXO6wixbpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joe-and-pats-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 316,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72892, 'longitude': -73.98411},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '168 1st Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['168 1st Ave', 'New York, NY 10009']},
#   'phone': '+12126774992',
#   'display_phone': '(212) 677-4992',
#   'distance': 417.11826546257817},
#  {'id': 'G9hV4H2iGpWD8RoUpjtokg',
#   'alias': 'l-industrie-pizzeria-new-york',
#   'name': 'L’industrie Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_ClrWIn3hJDFbf5UR0vtMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 71,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73323443774397, 'longitude': -74.0049081},
#   'transactions': [],
#   'location': {'address1': '104 Christopher St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['104 Christopher St', 'New York, NY 10014']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2221.7221777648815},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IBr5ZEI3nJBCwHYxcg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 6629,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 1437.9009195680994},
#  {'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwAOj0g9YKYey3V-Z6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1212,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 2513.3699148833057},
#  {'id': '9Qcxauog2gOTKt-L4Ljxxw',
#   'alias': 'burrata-basil-pizza-new-york',
#   'name': 'Burrata Basil Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/41VcPOjAc0FojmtKJBIwWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/burrata-basil-pizza-new-york?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 44,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7302, 'longitude': -73.98069},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '221 Ave A',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['221 Ave A', 'New York, NY 10009']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 387.4122952762239},
#  {'id': 'S8OKQ5S40oZ1Rr5RbC0jdg',
#   'alias': 'motorino-new-york-4',
#   'name': 'Motorino',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ebfvJxlqlBxp5xSKYi9wVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/motorino-new-york-4?adjust_creative=TqzhtA42spPSKOmzDuw9JA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TqzhtA42spPSKOmzDuw9JA',
#   'review_count': 1127,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73039, 'longitude': -73.98381},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '349 E 12th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['349 E 12th St', 'New York, NY 10003']},
#   'phone': '+12127772644',
#   'display_phone': '(212) 777-2644',
#   'distance': 516.1893282606604}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                alias  \
# 0   oOr6Ta5gZyDl6PyZ1cq7pg          east-village-pizza-new-york
# 1   -CCfu19Uuy_kD2t4ZwsQfA      village-square-pizza-new-york-3
# 2   zj8Lq1T8KIC5zwFief15jg       prince-street-pizza-new-york-2
# 3   WG639VkTjmK5dzydd1BBJA                  rubirosa-new-york-2
# 4   0UdC0VYX6aAvLiOcpR4MVQ                joes-pizza-new-york-7
# 5   vfYhEpp0x-DrNjC6GSJjPQ  artichoke-basilles-pizza-new-york-2
# 6   GyN4Kl0vFwziRN-h-Ow7ig                 saint-pizza-new-york
# 7   TWH4MjLtN1fKlF-7n6YXHg                lil-frankies-new-york
# 8   ow-zOxbslAoVw_uZ5UYoOA             chrissy-s-pizza-new-york
# 9   uc5qQMzs96rzjK27epDCug                joes-pizza-new-york-4
# 10  MeQU-nGaQvX12VXYOyzavQ   gruppo-nycthincrust-pizza-new-york
# 11  peV8B-MMMZb1mrC9r6rfAA               lucia-of-soho-new-york
# 12  vpkTNjq9dRh9rT3Nh0pe-A              nolita-pizza-new-york-2
# 13  ss0D4of03oe4SPsILObmNg      potenza-centrale-pizza-new-york
# 14  0ROpM3UcZhprN6dhwK2Hsw       joe-and-pats-pizzeria-new-york
# 15  G9hV4H2iGpWD8RoUpjtokg        l-industrie-pizzeria-new-york
# 16  WIhm0W9197f_rRtDziq5qQ           lombardis-pizza-new-york-4
# 17  v1DHGRNCH9247WLYoaoA9A        l-industrie-pizzeria-brooklyn
# 18  9Qcxauog2gOTKt-L4Ljxxw         burrata-basil-pizza-new-york
# 19  S8OKQ5S40oZ1Rr5RbC0jdg                  motorino-new-york-4
#
#                          name  \
# 0          East Village Pizza
# 1        Village Square Pizza
# 2         Prince Street Pizza
# 3                    Rubirosa
# 4                 Joe's Pizza
# 5   Artichoke Basille's Pizza
# 6                 Saint Pizza
# 7               Lil Frankie's
# 8             Chrissy’s Pizza
# 9                 Joe's Pizza
# 10  GRUPPO NYCThinCrust Pizza
# 11              Lucia of Soho
# 12               Nolita Pizza
# 13     Potenza Centrale Pizza
# 14       Joe & Pat's Pizzeria
# 15       L’industrie Pizzeria
# 16           Lombardi's Pizza
# 17       L'industrie Pizzeria
# 18        Burrata Basil Pizza
# 19                   Motorino
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/KOrE1e...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/3gFPiI...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/bckPg7...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrn...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/QXu6RG...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/4krjwP...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/6gTOBJ...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/t0OsEV...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/CPG7Wc...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/FKjd9R...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/4fE7bG...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/wO7d04...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/_BKVVo...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/zH0HoP...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/bvllEg...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/_ClrWI...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/lBq1IB...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/41VcPO...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/ebfvJx...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/east-village-pizza-ne...           531
# 1   https://www.yelp.com/biz/village-square-pizza-...           299
# 2   https://www.yelp.com/biz/prince-street-pizza-n...          5156
# 3   https://www.yelp.com/biz/rubirosa-new-york-2?a...          3242
# 4   https://www.yelp.com/biz/joes-pizza-new-york-7...          1083
# 5   https://www.yelp.com/biz/artichoke-basilles-pi...          4217
# 6   https://www.yelp.com/biz/saint-pizza-new-york?...            16
# 7   https://www.yelp.com/biz/lil-frankies-new-york...          1515
# 8   https://www.yelp.com/biz/chrissy-s-pizza-new-y...             1
# 9   https://www.yelp.com/biz/joes-pizza-new-york-4...          3096
# 10  https://www.yelp.com/biz/gruppo-nycthincrust-p...           278
# 11  https://www.yelp.com/biz/lucia-of-soho-new-yor...            19
# 12  https://www.yelp.com/biz/nolita-pizza-new-york...           238
# 13  https://www.yelp.com/biz/potenza-centrale-pizz...             6
# 14  https://www.yelp.com/biz/joe-and-pats-pizzeria...           316
# 15  https://www.yelp.com/biz/l-industrie-pizzeria-...            71
# 16  https://www.yelp.com/biz/lombardis-pizza-new-y...          6629
# 17  https://www.yelp.com/biz/l-industrie-pizzeria-...          1212
# 18  https://www.yelp.com/biz/burrata-basil-pizza-n...            44
# 19  https://www.yelp.com/biz/motorino-new-york-4?a...          1127
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 4              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 6              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 9              [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 11             [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 13             [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 14  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 16             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 18  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 19  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                           coordinates  \
# 0    {'latitude': 40.728212, 'longitude': -73.985182}
# 1      {'latitude': 40.72748, 'longitude': -73.98268}
# 2   {'latitude': 40.72308755605564, 'longitude': -...
# 3    {'latitude': 40.722766, 'longitude': -73.996233}
# 4      {'latitude': 40.73331, 'longitude': -73.98763}
# 5     {'latitude': 40.73216, 'longitude': -73.983877}
# 6   {'latitude': 40.72905715251202, 'longitude': -...
# 7    {'latitude': 40.723625, 'longitude': -73.988555}
# 8     {'latitude': 40.72742, 'longitude': -73.983531}
# 9   {'latitude': 40.73060076, 'longitude': -74.002...
# 10     {'latitude': 40.72474, 'longitude': -73.98161}
# 11  {'latitude': 40.721416405112784, 'longitude': ...
# 12  {'latitude': 40.7208883, 'longitude': -73.9962...
# 13  {'latitude': 40.72291908527927, 'longitude': -...
# 14     {'latitude': 40.72892, 'longitude': -73.98411}
# 15  {'latitude': 40.73323443774397, 'longitude': -...
# 16  {'latitude': 40.7215934960083, 'longitude': -7...
# 17     {'latitude': 40.71162, 'longitude': -73.95783}
# 18      {'latitude': 40.7302, 'longitude': -73.98069}
# 19     {'latitude': 40.73039, 'longitude': -73.98381}
#
#                 transactions price  \
# 0         [pickup, delivery]     $
# 1         [pickup, delivery]     $
# 2         [pickup, delivery]     $
# 3                   [pickup]    $$
# 4         [pickup, delivery]     $
# 5         [pickup, delivery]     $
# 6         [pickup, delivery]     $
# 7         [pickup, delivery]    $$
# 8                         []   NaN
# 9                 [delivery]     $
# 10        [pickup, delivery]    $$
# 11        [pickup, delivery]   NaN
# 12        [pickup, delivery]     $
# 13        [pickup, delivery]   NaN
# 14  [restaurant_reservation]    $$
# 15                        []   NaN
# 16        [pickup, delivery]    $$
# 17        [pickup, delivery]     $
# 18        [pickup, delivery]     $
# 19        [pickup, delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': '145 1st Ave', 'address2': '', 'a...  +12125294545
# 1   {'address1': '147 Ave A', 'address2': None, 'a...  +19176757709
# 2   {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 3   {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
# 4   {'address1': '150 E 14th St', 'address2': '', ...  +12123889474
# 5   {'address1': '321 E 14th St', 'address2': '', ...  +12122282004
# 6   {'address1': '223 Avenue B', 'address2': '', '...  +16463988250
# 7   {'address1': '19 1st Ave', 'address2': '', 'ad...  +12124204900
# 8   {'address1': '430 E 9th St', 'address2': '', '...
# 9   {'address1': '7 Carmine St', 'address2': '', '...  +12123661182
# 10  {'address1': '98 Ave  B', 'address2': '', 'add...  +12129952100
# 11  {'address1': '375 Canal St', 'address2': None,...
# 12  {'address1': '68 Kenmare St', 'address2': None...  +16468959131
# 13  {'address1': '38 Avenue B', 'address2': '', 'a...  +16468526995
# 14  {'address1': '168 1st Ave', 'address2': '', 'a...  +12126774992
# 15  {'address1': '104 Christopher St', 'address2':...
# 16  {'address1': '32 Spring St', 'address2': '', '...  +12129417994
# 17  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 18  {'address1': '221 Ave A', 'address2': '', 'add...
# 19  {'address1': '349 E 12th St', 'address2': '', ...  +12127772644
#
#      display_phone     distance
# 0   (212) 529-4545   469.929361
# 1   (917) 675-7709   249.475729
# 2   (212) 966-4100  1294.328146
# 3   (212) 965-0500  1441.826860
# 4   (212) 388-9474   968.586097
# 5   (212) 228-2004   684.947759
# 6   (646) 398-8250   297.880462
# 7   (212) 420-4900   795.591829
# 8                    317.800247
# 9   (212) 366-1182  1918.585269
# 10  (212) 995-2100   267.182295
# 11                  2141.874944
# 12  (646) 895-9131  1519.917463
# 13  (646) 852-6995   498.291249
# 14  (212) 677-4992   417.118265
# 15                  2221.722178
# 16  (212) 941-7994  1437.900920
# 17  (718) 599-0002  2513.369915
# 18                   387.412295
# 19  (212) 777-2644   516.189328

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 70

# %%
# Converting the JSON file to a dataframe
nydf = pd.read_json(JSON_FILE)

# %%
nydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 0 entries
# Empty DataFrame

# %%
# Dropping irrelevant columns that do not affect predicting the coorelation or good inspection scores to good yelp ratings
nydf.drop(['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 2
#       1 # Dropping irrelevant columns that do not affect predicting the coorelation or good inspection scores to good yelp ratings
# ----> 2 nydf.drop(['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'], axis=1, inplace=True)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['display_phone', 'phone', 'distance', 'price', 'id', 'is_closed'] not found in axis"

# %%
print(df['review_count'].unique())

# %%
# Function to filter out restaurants with 20 or fewer reviews
def filter_restaurants(df):
    filtered_dataframe = df[df['review_count'] >= 20]
    return filtered_dataframe

# executing function to eliminate restaurants with less than 20 reviews
df = filter_restaurants(df)

# %%
# Saving dataset to upload into other notebooks
df.to_csv('nydf', index=False)
