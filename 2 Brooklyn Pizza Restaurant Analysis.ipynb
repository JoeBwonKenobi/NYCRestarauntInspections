# %% [markdown]
# # **Brooklyn Pizza Restaurant Analysis**

# %% [markdown]
# Joseph Lardie
#
# December 2023

# %% [markdown]
# # **Imports**

# %%
#Numpy
import numpy as np

#Pandas
import pandas as pd

#Seaborn
import seaborn as sns

#matplotlib
import matplotlib.pyplot as plt
import plotly
# %matplotlib inline

from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords

#Geospatial
import geopandas as gpd
import folium

#Sklearn preprocessing
from sklearn import preprocessing,set_config
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder,StandardScaler,LabelEncoder
from sklearn.neighbors import NearestNeighbors
from sklearn.impute import SimpleImputer

#Scipy
from scipy import stats
from scipy.stats import norm

# Warnings
import warnings
warnings.filterwarnings("ignore")
set_config(display = 'diagram')

# %% [markdown]
# # **Import Data**

# %%
# Loading merged Brooklyn Pizza Restaurants Data
mdf = pd.read_csv('mdf')

# %%
# Ensuring the data loaded correctly
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CAMIS                  607 non-null    int64
#  1   DBA                    607 non-null    object
#  2   BORO                   607 non-null    object
#  3   BUILDING               607 non-null    object
#  4   STREET                 607 non-null    object
#  5   ZIPCODE                603 non-null    float64
#  6   CUISINE DESCRIPTION    607 non-null    object
#  7   INSPECTION DATE        607 non-null    object
#  8   ACTION                 607 non-null    object
#  9   VIOLATION CODE         604 non-null    object
#  10  VIOLATION DESCRIPTION  604 non-null    object
#  11  CRITICAL FLAG          607 non-null    object
#  12  SCORE                  607 non-null    float64
#  13  GRADE                  607 non-null    object
#  14  GRADE DATE             607 non-null    object
#  15  INSPECTION TYPE        607 non-null    object
#  16  Latitude               607 non-null    float64
#  17  Longitude              607 non-null    float64
#  18  Council District       603 non-null    float64
#  19  alias                  607 non-null    object
#  20  name                   607 non-null    object
#  21  image_url              607 non-null    object
#  22  url                    607 non-null    object
#  23  review_count           607 non-null    int64
#  24  categories             607 non-null    object
#  25  rating                 607 non-null    float64
#  26  coordinates            607 non-null    object
#  27  transactions           607 non-null    object
#  28  location               607 non-null    object
#  29  _merge                 607 non-null    object
# dtypes: float64(6), int64(2), object(22)
# memory usage: 142.4+ KB

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## **Longitude and Latitude**

# %%
# Function to clean up longitude and latitude
def clean_coordinates(coord):
    try:
        # Convert to float
        coord = float(coord)
        
        # Ensure that longitude is in the range [-180, 180]
        if coord < -180 or coord > 180:
            return None  
        else:
            return coord
    except ValueError:
        return None  

# Apply the cleaning function to 'Longitude' and 'Latitude' columns
mdf['Longitude'] = mdf['Longitude'].apply(clean_coordinates)
mdf['Latitude'] = mdf['Latitude'].apply(clean_coordinates)

# Drop rows with missing or invalid coordinates
mdf = mdf.dropna(subset=['Longitude', 'Latitude'])

# %% [markdown]
# ## **Outliers**

# %%
# Function to calculate z-score for a column
def calculate_zscore(column):
    z_scores = (column - column.mean()) / column.std()
    return z_scores

# Calculate z-scores for 'Longitude' and 'Latitude'
z_scores_longitude = calculate_zscore(mdf['Longitude'])
z_scores_latitude = calculate_zscore(mdf['Latitude'])

# Set a threshold for z-scores (e.g., 3 standard deviations)
z_threshold = 3

# Identify and remove outliers based on the threshold
outliers = (np.abs(z_scores_longitude) > z_threshold) | (np.abs(z_scores_latitude) > z_threshold)
mdf = mdf[~outliers]

# %% [markdown]
# # **Feature Engineering**

# %%
# Create a new column 'Restaurant Chain Indicator'
mdf['Chain Indicator'] = mdf['DBA'].duplicated(keep=False)

# %%
# Create a new column 'Full Address'
mdf['Full Address'] = mdf['BUILDING'] + ' ' + mdf['STREET']

# %%
# Define size categories
size_bins = [50, 100, 200, np.inf]
size_labels = ['Small', 'Medium', 'Large']

# Create 'Size Category' column
mdf['Size Category'] = pd.cut(mdf['review_count'], bins=size_bins, labels=size_labels)

# %% [markdown]
# # **Visualizations**

# %% [markdown]
# ## **Top 20 rated**

# %%
# Sort in descending order and select the top 20 rated restaurants
top_rated_restaurants = mdf.sort_values(by='rating', ascending=False).head(20)
print(top_rated_restaurants)
# Out:
#         CAMIS                     DBA      BORO BUILDING               STREET  \
# 217  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 218  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 219  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 220  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 221  50102007  ROME TO BROOKLYN PIZZA  Brooklyn      755         GRAND STREET
# 394  50141293          CHAMPION PIZZA  Brooklyn     1196        FULTON STREET
# 281  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 92   50116710            BROOKLYN DOP  Brooklyn      237             5 AVENUE
# 90   50116710            BROOKLYN DOP  Brooklyn      237             5 AVENUE
# 270  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 271  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 272  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 273  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 274  50055359                     OPS  Brooklyn      346        HIMROD STREET
# 569  50086826          SAL'S PIZZERIA  Brooklyn      544       LORIMER STREET
# 572  50125089          SAL'S PIZZERIA  Brooklyn      119       WYCKOFF AVENUE
# 283  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 575  50125089          SAL'S PIZZERIA  Brooklyn      119       WYCKOFF AVENUE
# 282  50056980                 FAZIO'S  Brooklyn      709    KNICKERBOCKER AVE
# 263  50089510            ROSA'S PIZZA  Brooklyn      374  METROPOLITAN AVENUE
#
#      ZIPCODE CUISINE DESCRIPTION INSPECTION DATE  \
# 217  11211.0               Pizza      08/18/2021
# 218  11211.0               Pizza      08/18/2021
# 219  11211.0               Pizza      08/18/2021
# 220  11211.0               Pizza      01/23/2023
# 221  11211.0               Pizza      01/23/2023
# 394  11216.0               Pizza      10/25/2023
# 281  11221.0               Pizza      12/19/2023
# 92   11215.0               Pizza      03/22/2023
# 90   11215.0               Pizza      03/22/2023
# 270  11237.0               Pizza      01/22/2020
# 271  11237.0               Pizza      01/22/2020
# 272  11237.0               Pizza      12/10/2022
# 273  11237.0               Pizza      01/22/2020
# 274  11237.0               Pizza      12/10/2022
# 569  11211.0               Pizza      11/15/2022
# 572  11237.0               Pizza      12/06/2022
# 283  11221.0               Pizza      12/19/2023
# 575  11237.0               Pizza      02/12/2024
# 282  11221.0               Pizza      08/05/2021
# 263  11211.0               Pizza      11/06/2023
#
#                                               ACTION VIOLATION CODE  ...  \
# 217  Violations were cited in the following area(s).            10B  ...
# 218  Violations were cited in the following area(s).            06B  ...
# 219  Violations were cited in the following area(s).            06F  ...
# 220  Violations were cited in the following area(s).            06D  ...
# 221  Violations were cited in the following area(s).            10F  ...
# 394  Violations were cited in the following area(s).            10F  ...
# 281  Violations were cited in the following area(s).            04L  ...
# 92   Violations were cited in the following area(s).            06D  ...
# 90   Violations were cited in the following area(s).            10B  ...
# 270  Violations were cited in the following area(s).            06D  ...
# 271  Violations were cited in the following area(s).            06C  ...
# 272  Violations were cited in the following area(s).            06D  ...
# 273  Violations were cited in the following area(s).            10F  ...
# 274  Violations were cited in the following area(s).            02G  ...
# 569  Violations were cited in the following area(s).            08A  ...
# 572  Violations were cited in the following area(s).            10F  ...
# 283  Violations were cited in the following area(s).            02B  ...
# 575  Violations were cited in the following area(s).            02B  ...
# 282  Violations were cited in the following area(s).            06C  ...
# 263  Violations were cited in the following area(s).            10G  ...
#
#     review_count                                         categories  rating  \
# 217          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 218          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 219          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 220          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 221          166  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 394          439             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 281          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 92            45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 90            45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 270          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 271          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 272          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 273          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 274          200  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 569           59             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 572           59             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 283          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 575           59             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 282          215  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 263          320  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                            coordinates  \
# 217  {'latitude': 40.711886016839244, 'longitude': ...
# 218  {'latitude': 40.711886016839244, 'longitude': ...
# 219  {'latitude': 40.711886016839244, 'longitude': ...
# 220  {'latitude': 40.711886016839244, 'longitude': ...
# 221  {'latitude': 40.711886016839244, 'longitude': ...
# 394  {'latitude': 40.7215270996094, 'longitude': -7...
# 281     {'latitude': 40.69442, 'longitude': -73.91039}
# 92       {'latitude': 40.67526, 'longitude': -73.9811}
# 90       {'latitude': 40.67526, 'longitude': -73.9811}
# 270      {'latitude': 40.70276, 'longitude': -73.9171}
# 271      {'latitude': 40.70276, 'longitude': -73.9171}
# 272      {'latitude': 40.70276, 'longitude': -73.9171}
# 273      {'latitude': 40.70276, 'longitude': -73.9171}
# 274      {'latitude': 40.70276, 'longitude': -73.9171}
# 569     {'latitude': 40.69276, 'longitude': -73.85883}
# 572     {'latitude': 40.69276, 'longitude': -73.85883}
# 283     {'latitude': 40.69442, 'longitude': -73.91039}
# 575     {'latitude': 40.69276, 'longitude': -73.85883}
# 282     {'latitude': 40.69442, 'longitude': -73.91039}
# 263   {'latitude': 40.712192, 'longitude': -73.899997}
#
#                transactions  \
# 217  ['pickup', 'delivery']
# 218  ['pickup', 'delivery']
# 219  ['pickup', 'delivery']
# 220  ['pickup', 'delivery']
# 221  ['pickup', 'delivery']
# 394  ['delivery', 'pickup']
# 281  ['delivery', 'pickup']
# 92                       []
# 90                       []
# 270            ['delivery']
# 271            ['delivery']
# 272            ['delivery']
# 273            ['delivery']
# 274            ['delivery']
# 569  ['delivery', 'pickup']
# 572  ['delivery', 'pickup']
# 283  ['delivery', 'pickup']
# 575  ['delivery', 'pickup']
# 282  ['delivery', 'pickup']
# 263                      []
#
#                                               location  _merge  \
# 217  {'address1': '755 Grand St', 'address2': None,...    both
# 218  {'address1': '755 Grand St', 'address2': None,...    both
# 219  {'address1': '755 Grand St', 'address2': None,...    both
# 220  {'address1': '755 Grand St', 'address2': None,...    both
# 221  {'address1': '755 Grand St', 'address2': None,...    both
# 394  {'address1': '17 Cleveland Pl', 'address2': No...    both
# 281  {'address1': '709 Knickerbocker Ave', 'address...    both
# 92   {'address1': '237 5th Ave', 'address2': '', 'a...    both
# 90   {'address1': '237 5th Ave', 'address2': '', 'a...    both
# 270  {'address1': '346 Himrod St', 'address2': None...    both
# 271  {'address1': '346 Himrod St', 'address2': None...    both
# 272  {'address1': '346 Himrod St', 'address2': None...    both
# 273  {'address1': '346 Himrod St', 'address2': None...    both
# 274  {'address1': '346 Himrod St', 'address2': None...    both
# 569  {'address1': '8507 Jamaica Ave', 'address2': '...    both
# 572  {'address1': '8507 Jamaica Ave', 'address2': '...    both
# 283  {'address1': '709 Knickerbocker Ave', 'address...    both
# 575  {'address1': '8507 Jamaica Ave', 'address2': '...    both
# 282  {'address1': '709 Knickerbocker Ave', 'address...    both
# 263  {'address1': '6265 Fresh Pond Rd', 'address2':...    both
#
#      Chain Indicator             Full Address Size Category
# 217             True         755 GRAND STREET        Medium
# 218             True         755 GRAND STREET        Medium
# 219             True         755 GRAND STREET        Medium
# 220             True         755 GRAND STREET        Medium
# 221             True         755 GRAND STREET        Medium
# 394             True       1196 FULTON STREET         Large
# 281             True    709 KNICKERBOCKER AVE         Large
# 92              True             237 5 AVENUE           NaN
# 90              True             237 5 AVENUE           NaN
# 270             True        346 HIMROD STREET        Medium
# 271             True        346 HIMROD STREET        Medium
# 272             True        346 HIMROD STREET        Medium
# 273             True        346 HIMROD STREET        Medium
# 274             True        346 HIMROD STREET        Medium
# 569             True       544 LORIMER STREET         Small
# 572             True       119 WYCKOFF AVENUE         Small
# 283             True    709 KNICKERBOCKER AVE         Large
# 575             True       119 WYCKOFF AVENUE         Small
# 282             True    709 KNICKERBOCKER AVE         Large
# 263             True  374 METROPOLITAN AVENUE         Large
#
# [20 rows x 33 columns]

# %%
# Group by 'name' and calculate the mean rating for each restaurant
mean_ratings = mdf.groupby('name')['rating'].mean().reset_index()

# Sort by mean rating in descending order and select the top 20
top_rated_restaurants = mean_ratings.sort_values(by='rating', ascending=False).head(20)

# Create a vertical bar plot
plt.figure(figsize=(12, 8))
plt.bar(top_rated_restaurants['name'], top_rated_restaurants['rating'], color='skyblue')
plt.xlabel('Restaurant Name')
plt.ylabel('Average Rating')
plt.title('Top 20 Highest-Rated Restaurants (Average Rating)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## **Top 20 review count**

# %%
# Group by 'name' and calculate the total review count for each restaurant
total_reviews = mdf.groupby('name')['review_count'].sum().reset_index()

# Sort by total review count in descending order and select the top 20
top_reviewed_restaurants = total_reviews.sort_values(by='review_count', ascending=False).head(20)

# Create a vertical bar plot
plt.figure(figsize=(12, 8))
plt.bar(top_reviewed_restaurants['name'], top_reviewed_restaurants['review_count'], color='salmon')
plt.xlabel('Restaurant Name')
plt.ylabel('Total Review Count')
plt.title('Top 20 Restaurants with the Most Reviews')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# ## **Size Category count**

# %%
# Count the number of restaurants in each size category
size_category_counts = mdf['Size Category'].value_counts()

# Create a vertical bar plot
plt.figure(figsize=(10, 6))
size_category_counts.plot(kind='bar', color='lightgreen')
plt.xlabel('Size Category')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Restaurants by Size Category')
plt.xticks(rotation=0, ha='center')  # Rotate x-axis labels if needed
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## **Geospatial**

# %%
# Create a GeoDataFrame from the DataFrame
geometry = gpd.points_from_xy(mdf['Longitude'], mdf['Latitude'])
gdf = gpd.GeoDataFrame(mdf, geometry=geometry)

# Plot using GeoPandas and Matplotlib
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(color='lightgrey', edgecolor='black')
gdf.plot(ax=ax, marker='o', color='red', markersize=10, alpha=0.5)
plt.title('Geospatial Visualization with GeoPandas and Matplotlib')
plt.show()

# Creating an interactive map using Folium
m = folium.Map(location=[mdf['Latitude'].mean(), mdf['Longitude'].mean()], zoom_start=1)

for index, row in mdf.iterrows():
    popup_content = (
        f"Name: {row['name']}<br>"
        f"Latitude: {row['Latitude']}, Longitude: {row['Longitude']}<br>"
        f"Rating: {row['rating']}<br>"
        f"Review Count: {row['review_count']}<br>"
        f"SCORE: {row['SCORE']}<br>"
        f"Size Category: {row['Size Category']}<br>"
        f"Full Address: {row['Full Address']}<br>"
        f"Chain Indicator: {row['Chain Indicator']}<br>"
        f"Transaction: {row['transactions']}<br>"
        f"Grade: {row['GRADE']}"
    )

    # Create a marker with the customized popup content and add it to the map
    folium.Marker([row['Latitude'], row['Longitude']], popup=folium.Popup(popup_content, max_width=300)).add_to(m)

# Save the map to an HTML file
m.save('Brooklyn_Pizza_map.html')

# Showing the geospatial viz
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52b512676030a9ab186c032541c4d0e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52b512676030a9ab186c032541c4d0e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52b512676030a9ab186c032541c4d0e5 = L.map(
#                 &quot;map_52b512676030a9ab186c032541c4d0e5&quot;,
#                 {
#                     center: [40.68213249019692, -73.96461563267802],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2653baf9eac933c1da8e54f88c2358b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52b512676030a9ab186c032541c4d0e5);
#
#
#             var marker_45baabad4b2e8c06971d5396ba3097cd = L.marker(
#                 [40.705025904601, -73.933228565237],
#                 {}
#             ).addTo(map_52b512676030a9ab186c032541c4d0e5);
#
#
#         var popup_1b34f7aa0d94a38b9a510fe578715d17 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3f206dba6490a5758c357484f6b030bd = $(`&lt;div id=&quot;html_3f206dba6490a5758c357484f6b030bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROBERTA&#x27;S&lt;br&gt;Latitude: 40.705025904601, Longitude: -73.933228565237&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 3322&lt;br&gt;SCORE: 16.0&lt;br&gt;Size Category: Large&lt;br&gt;Full Address: 43 BOGART STREET&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: [&#x27;pickup&#x27;, &#x27;delivery&#x27;]&lt;br&gt;Grade: B&lt;/div&gt;`)[0];
#                 popup_1b34f7aa0d94a38b9a510fe578715d17.setContent(html_3f206dba6490a5758c357484f6b030bd);
#
#
#
#         marker_45baabad4b2e8c06971d5396ba3097cd.bindPopup(popup_1b34f7aa0d94a38b9a510fe578715d17)
#         ;
#
#
#
#
#             var marker_40cf09b739d4b76b77d5f8363f152751 = L.marker(
#                 [40.705025904601, -73.933228565237],
#                 {}
#             ).addTo(map_52b512676030a9ab186c032541c4d0e5);
#
#
#         var popup_b752838e0fefab4543e358e75b6432f0 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5e712185e064797f7afd9e204b6aef63 = $(`&lt;div id=&quot;html_5e712185e064797f7afd9e204b6aef63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROBERTA&#x27;S&lt;br&gt;Latitude: 40.705025904601, Longitude: -73.933228565237&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 101&lt;br&gt;SCORE: 16.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 43 BOGART STREET&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: [&#x27;delivery&#x27;, &#x27;pickup&#x27;]&lt;br&gt;Grade: B&lt;/div&gt;`)[0];
#                 popup_b752838e0fefab4543e358e75b6432f0.setContent(html_5e712185e064797f7afd9e204b6aef63);
#
#
#
#         marker_40cf09b739d4b76b77d5f8363f152751.bindPopup(popup_b752838e0fefab4543e358e75b6432f0)
#         ;
#
#
#
#
#             var marker_f9f32f19483fa87e9e5a8e6c07e9afd0 = L.marker(
#                 [40.716387401023, -73.966743847724],
#                 {}
#             ).addTo(map_52b512676030a9ab186c032541c4d0e5);
#
#
#         var popup_ec96616ecebcd8d0da588a5b27bf8791 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_2288452287bc044ade7dfded829e0ca1 = $(`&lt;div id=&quot;html_2288452287bc044ade7dfded829e0ca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROBERTA&#x27;S&lt;br&gt;Latitude: 40.716387401023, Longitude: -73.966743847724&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 3322&lt;br&gt;SCORE: 13.0&lt;br&gt;Size Category: Large&lt;br&gt;Full Address: 6 GRAND STREET&lt;br&gt;Chain Indicator: True&lt;br&gt;Transaction: [&#x27;pickup&#x27;, &#x27;delivery&#x27;]&lt;br&gt;Grade: A&lt;/div&gt;`)[0];
#                 popup_ec96616ecebcd8d0da588a5b27bf8791.setContent(html_2288452287bc044ade7dfded829e0ca1);
#
#
#
#         marker_f9f32f19483fa87e9e5a8e6c07e9afd0.bindPopup(popup_ec96616ecebcd8d0da588a5b27bf8791)
#         ;
#
#
#
#
#             var marker_dfa98a37e381a2dc9c4c9370b1725409 = L.marker(
#                 [40.716387401023, -73.966743847724],
#                 {}
#             ).addTo(map_52b512676030a9ab186c032541c4d0e5);
#
#
#         var popup_929b88efabf155022d9e117dbd5a6735 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_077238a1abe915d4c7c8549001f37aa6 = $(`&lt;div id=&quot;html_077238a1abe915d4c7c8549001f37aa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: ROBERTA&#x27;S&lt;br&gt;Latitude: 40.716387401023, Longitude: -73.966743847724&lt;br&gt;Rating: 4.0&lt;br&gt;Review Count: 101&lt;br&gt;SCORE: 13.0&lt;br&gt;Size Category: Medium&lt;br&gt;Full Address: 6 GRAND
